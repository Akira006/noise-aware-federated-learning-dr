# %% [markdown]
# # Exp3 Noise Aware Fl — EfficientNetB0
# **Project:** Noise-Aware Federated Learning for Robust Diabetic Retinopathy Classification
# **Model:** EfficientNetB0 (ImageNet pretrained)
# **Paradigm:** Noise-Aware FedAvg — 3 clients, stochastic noise aug semua client
#
# | Config | Value |
# |--------|-------|
# | Datasets | DDR + EyePACS + APTOS |
# | Split | 70:15:15 stratified per-client |
# | Noise aug (training) | ✅ Stochastic (50% prob, semua client) |
# | Test | Clean + Noisy (seed=123, identik di 3 notebook) |
#
# > ⚠️ **JANGAN ubah `SEED` dan `NOISY_TEST_SEED`** — harus konsisten di 3 notebook.

# %% [markdown]
# ## 1. GPU Check

# %%
# !nvidia-smi
# Out:
# Sun Jun  7 01:40:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             54W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 2. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3. Imports

# %%
import os, json, random, time, gc, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    confusion_matrix, accuracy_score,
    precision_recall_fscore_support,
    roc_auc_score, roc_curve, auc, cohen_kappa_score
)
from sklearn.preprocessing import label_binarize

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.applications import EfficientNetB0

print("TF:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 4. Configuration

# %%
# ── REPRODUCIBILITY (sama di 3 notebook) ─────────────────────────
SEED             = 42
NOISY_TEST_SEED  = 123
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── MODEL & EXPERIMENT ────────────────────────────────────────────
MODEL_NAME       = "EfficientNetB0"
EXPERIMENT_NAME  = "exp3_noise_aware_fl"

# ── TRAINING ──────────────────────────────────────────────────────
IMG_SIZE         = (224, 224)
NUM_CLASSES      = 5
BATCH_SIZE       = 32
LR               = 1e-4
UNFREEZE_N       = 10
DROPOUT          = 0.4
L2               = 1e-4
# ── FL CONFIG ─────────────────────────────────────────────────────
FL_ROUNDS        = 60
LOCAL_EPOCHS     = 2
STAGE1_ROUNDS    = 27
STAGE2_ROUNDS    = 33
CLIENT_NAMES     = ["DDR","EyePACS","APTOS"]
USE_NOISE_AUG    = True
NOISY_CLIENTS    = ["DDR","EyePACS","APTOS"]   # semua client — sesuai Fig 2c paper

# ── NOISE PARAMS
NS_MIN, NS_MAX   = 0.01, 0.05     # Gaussian noise sigma
BL_MIN, BL_MAX   = 1.0,  3.0     # Gaussian blur sigma
BR_DELTA         = 0.2            # Brightness delta
CT_LOW, CT_HIGH  = 0.7,  1.3     # Contrast range
NOISE_PROB       = 0.5            # Probability per degradation type
BLUR_PROB        = 0.5
BRIGHT_PROB      = 0.5

CLASS_NAMES  = ["No DR","Mild","Moderate","Severe","Proliferative"]

# ── PATHS ─────────────────────────────────────────────────────────
PROJECT  = "/content/drive/MyDrive/Binus/Semester_4/Research_Methodology"
DS_BASE  = "/content/drive/MyDrive/S-Class/Orion/OrionFL"
BALANCED_DIR = f"{DS_BASE}/balanced"

APTOS_NPZ  = f"{DS_BASE}/balanced/aptos_balanced.npz"
DDR_NPZ    = f"{DS_BASE}/balanced/ddr_balanced.npz"
EYE_NPZ    = f"{DS_BASE}/balanced/eyepacs_balanced.npz"

RES      = f"{PROJECT}/Result/{MODEL_NAME}/{EXPERIMENT_NAME}"
MDL_DIR  = f"{RES}/models"
LOG_DIR  = f"{RES}/logs"
FIG_DIR  = f"{RES}/figures"
for d in [MDL_DIR, LOG_DIR, FIG_DIR]: os.makedirs(d, exist_ok=True)

print(f"Model      : {MODEL_NAME}")
print(f"Experiment : {EXPERIMENT_NAME}")
print(f"Results    : {RES}")
# Out:
# Model      : EfficientNetB0
# Experiment : exp3_noise_aware_fl
# Results    : /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/EfficientNetB0/exp3_noise_aware_fl

# %% [markdown]
# ## 5. Load & Split Per Client (70:15:15)

# %%
def to01(X):
    X = X.astype(np.float32)
    return X / 255.0 if X.max() > 1.0 else X

def split_dataset(X, y, seed=SEED):
    X_tr,X_tmp,y_tr,y_tmp = train_test_split(X,y,test_size=.30,random_state=seed,stratify=y)
    X_v,X_te,y_v,y_te     = train_test_split(X_tmp,y_tmp,test_size=.50,random_state=seed,stratify=y_tmp)
    return X_tr,X_v,X_te,y_tr,y_v,y_te

# ── DDR ───────────────────────────────────────────────────────────
print("Loading DDR...")
d = np.load(DDR_NPZ, allow_pickle=True)
_img_key = "X" if "X" in d.files else "images"
_lbl_key = "y" if "y" in d.files else "labels"
X_ddr, y_ddr = to01(d[_img_key]), d[_lbl_key].astype(np.int64)
print(f"  keys: img=\'{_img_key}\' lbl=\'{_lbl_key}\' | {X_ddr.shape}")

# ── EyePACS ───────────────────────────────────────────────────────
print("Loading EyePACS...")
d = np.load(EYE_NPZ, allow_pickle=True)
X_eye = to01(d["images"])
if "labels" in d.files:
    y_eye = d["labels"].astype(np.int64)
    print(f"  label source: NPZ internal | {X_eye.shape}")
else:
    y_eye = pd.read_csv(EYE_CSV)["level"].values.astype(np.int64)
    print(f"  label source: CSV | {X_eye.shape}")
assert len(X_eye) == len(y_eye), f"Mismatch: {len(X_eye)} vs {len(y_eye)}"

# ── APTOS ─────────────────────────────────────────────────────────
print("Loading APTOS...")
d = np.load(APTOS_NPZ, allow_pickle=True)
X_apt, y_apt = to01(d["images"]), d["labels"].astype(np.int64)
print(f"  {X_apt.shape}")

# ── Split & FL Client Assignment ──────────────────────────────────
Xtr_d,Xv_d,Xte_d,ytr_d,yv_d,yte_d = split_dataset(X_ddr, y_ddr)
Xtr_e,Xv_e,Xte_e,ytr_e,yv_e,yte_e = split_dataset(X_eye, y_eye)
Xtr_a,Xv_a,Xte_a,ytr_a,yv_a,yte_a = split_dataset(X_apt, y_apt)
print(f"DDR     train:{len(ytr_d):>6,}  val:{len(yv_d):>5,}  test:{len(yte_d):>5,}")
print(f"EyePACS train:{len(ytr_e):>6,}  val:{len(yv_e):>5,}  test:{len(yte_e):>5,}")
print(f"APTOS   train:{len(ytr_a):>6,}  val:{len(yv_a):>5,}  test:{len(yte_a):>5,}")

Xtr = [Xtr_d, Xtr_e, Xtr_a]
ytr = [ytr_d, ytr_e, ytr_a]
csz = [len(ytr_d), len(ytr_e), len(ytr_a)]

X_val    = np.concatenate([Xv_d,  Xv_e,  Xv_a])
y_val    = np.concatenate([yv_d,  yv_e,  yv_a])
X_test   = np.concatenate([Xte_d, Xte_e, Xte_a])
y_test   = np.concatenate([yte_d, yte_e, yte_a])
src_test = np.array(["DDR"]*len(yte_d)+["EyePACS"]*len(yte_e)+["APTOS"]*len(yte_a))

print(f"\nClient sizes : {dict(zip(CLIENT_NAMES, csz))}")
print(f"Val          : {len(y_val):,}  |  Test: {len(y_test):,}")
for name, y in zip(CLIENT_NAMES, ytr):
    dist = dict(zip(*np.unique(y, return_counts=True)))
    print(f"  {name} dist : {dist}")

del X_ddr, X_eye, X_apt; gc.collect()
# Out:
# Loading DDR...
#   keys: img='images' lbl='labels' | (3729, 224, 224, 3)
# Loading EyePACS...
#   label source: NPZ internal | (8581, 224, 224, 3)
# Loading APTOS...
#   (1858, 224, 224, 3)
# DDR     train: 2,610  val:  559  test:  560
# EyePACS train: 6,006  val:1,287  test:1,288
# APTOS   train: 1,300  val:  279  test:  279
#
# Client sizes : {'DDR': 2610, 'EyePACS': 6006, 'APTOS': 1300}
# Val          : 2,125  |  Test: 2,127
#   DDR dist : {np.int64(0): np.int64(735), np.int64(1): np.int64(441), np.int64(2): np.int64(630), np.int64(3): np.int64(165), np.int64(4): np.int64(639)}
#   EyePACS dist : {np.int64(0): np.int64(2100), np.int64(1): np.int64(1400), np.int64(2): np.int64(1400), np.int64(3): np.int64(611), np.int64(4): np.int64(495)}
#   APTOS dist : {np.int64(0): np.int64(350), np.int64(1): np.int64(259), np.int64(2): np.int64(350), np.int64(3): np.int64(135), np.int64(4): np.int64(206)}
# 66

# %% [markdown]
# ## 6. Class Weights

# %%
def get_cw(y):
    cls = np.unique(y)
    cw  = compute_class_weight("balanced", classes=cls, y=y)
    d   = {int(c):float(w) for c,w in zip(cls,cw)}
    for c in range(NUM_CLASSES): d.setdefault(c, 1.0)
    return d
cws = [get_cw(y) for y in ytr]
for name,cw in zip(CLIENT_NAMES,cws): print(f"{name}: {cw}")
# Out:
# DDR: {0: 0.710204081632653, 1: 1.183673469387755, 2: 0.8285714285714286, 3: 3.1636363636363636, 4: 0.8169014084507042}
# EyePACS: {0: 0.572, 1: 0.858, 2: 0.858, 3: 1.9659574468085106, 4: 2.4266666666666667}
# APTOS: {0: 0.7428571428571429, 1: 1.0038610038610039, 2: 0.7428571428571429, 3: 1.9259259259259258, 4: 1.2621359223300972}

# %% [markdown]
# ## 7. Noise Pipeline

# %%
def gauss_noise(img,sigma): return np.clip(img+np.random.normal(0,sigma,img.shape).astype(np.float32),0,1)
# SESUDAH (fix):
def gauss_blur(img, sigma):
    out = np.empty_like(img)
    for ch in range(img.shape[2]):
        out[:, :, ch] = gaussian_filter(img[:, :, ch], sigma=sigma)
    return np.clip(out.astype(np.float32), 0, 1)
def bright_contrast(img,bd,cf): m=img.mean(); return np.clip(((img-m)*cf+m+bd).astype(np.float32),0,1)

def stochastic_degrade(img):
    rng = np.random.default_rng()
    img = img.copy()
    if rng.random() < NOISE_PROB:  img = gauss_noise(img,     rng.uniform(NS_MIN,NS_MAX))
    if rng.random() < BLUR_PROB:   img = gauss_blur(img,      rng.uniform(BL_MIN,BL_MAX))
    if rng.random() < BRIGHT_PROB: img = bright_contrast(img, rng.uniform(-BR_DELTA,BR_DELTA), rng.uniform(CT_LOW,CT_HIGH))
    return img

def deterministic_degrade(img, rng):
    img = img.copy()
    img = gauss_noise(img,     rng.uniform(NS_MIN,NS_MAX))
    img = gauss_blur(img,      rng.uniform(BL_MIN,BL_MAX))
    img = bright_contrast(img, rng.uniform(-BR_DELTA,BR_DELTA), rng.uniform(CT_LOW,CT_HIGH))
    return img

def make_noisy_set(X, seed=NOISY_TEST_SEED):
    print(f"  Generating noisy test set (n={len(X)}, seed={seed})...")
    rng = np.random.default_rng(seed); out = np.empty_like(X)
    for i in range(len(X)): out[i] = deterministic_degrade(X[i], rng)
    print(f"  Done. range=[{out.min():.3f},{out.max():.3f}]")
    return out

X_test_noisy = make_noisy_set(X_test)
# Out:
#   Generating noisy test set (n=2127, seed=123)...
#   Done. range=[0.000,1.000]

# %% [markdown]
# ## 8. Build EfficientNetB0
#
# > **Catatan EfficientNetB0 vs MobileNetV2:**
# > EfficientNetB0 sudah include rescaling internal (0-255 → normalized),
# > jadi input `[0,1]` tetap aman karena kita normalize manual sebelumnya.
# > `training=False` di inference mode penting untuk BatchNorm consistency.

# %%
AUT = tf.data.AUTOTUNE

def make_ds(X, y, shuffle=False, seed=None):
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).prefetch(AUT)

def make_noisy_train_ds(X, y, shuffle=True, seed=None):
    def tf_aug(x, label):
        def np_aug(img_np):
            return stochastic_degrade(img_np.numpy()).astype(np.float32)
        x_aug = tf.py_function(np_aug, [x], tf.float32)
        x_aug.set_shape(x.shape)
        return x_aug, label
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).map(tf_aug, num_parallel_calls=AUT).prefetch(AUT)

def build_model(stage=1):
    base = EfficientNetB0(include_top=False, weights="imagenet", input_shape=(224,224,3))
    base.trainable = False
    if stage == 2:
        base.trainable = True
        for l in base.layers[:-UNFREEZE_N]: l.trainable = False
        for l in base.layers[-UNFREEZE_N:]: l.trainable = True
        for l in base.layers:
            if isinstance(l, layers.BatchNormalization): l.trainable = False
    inp = keras.Input((224,224,3))
    # EfficientNetB0 has built-in Rescaling(1/255) + Normalization layers internally.
    # Our pipeline normalizes to [0,1] per paper Section III.A, so we scale back
    # to [0,255] here before entering the backbone — implementation detail only,
    # methodology (normalize to [0,1]) remains consistent with the draft paper.
    x   = inp * 255.0
    x   = base(x, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dropout(DROPOUT)(x)
    out = layers.Dense(NUM_CLASSES, activation="softmax",
                       kernel_regularizer=regularizers.l2(L2))(x)
    return keras.Model(inp, out)

def fedavg(weights_list, sizes):
    total = sum(sizes)
    return [np.sum([weights_list[i][li]*(sizes[i]/total) for i in range(len(sizes))],axis=0)
            for li in range(len(weights_list[0]))]

val_ds     = make_ds(X_val, y_val)
test_clean = make_ds(X_test, y_test)
test_noisy = make_ds(X_test_noisy, y_test)
print("Model + dataset helpers ready.")
# Out:
# Model + dataset helpers ready.

# %% [markdown]
# ## 9. Local Training Function

# %%
def local_train(global_w, X, y, cw, client_name, stage, seed):
    m = build_model(stage)
    m.set_weights(global_w)
    m.compile(optimizer=keras.optimizers.Adam(LR),
               loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])

    if client_name in NOISY_CLIENTS:
        ds  = make_noisy_train_ds(X, y, shuffle=True, seed=seed)
        tag = "[+NOISE]"
    else:
        ds  = make_ds(X, y, shuffle=True, seed=seed)
        tag = "[clean]"

    h   = m.fit(ds, epochs=LOCAL_EPOCHS, class_weight=cw, verbose=0)
    w,loss,acc = m.get_weights(), h.history["loss"][-1], h.history["accuracy"][-1]
    del m, ds; tf.keras.backend.clear_session(); gc.collect()
    return w, float(loss), float(acc), tag

print("local_train ready.")
# Out:
# local_train ready.

# %% [markdown]
# ## 10. FL Training Loop

# %%
# ── EARLY STOPPING CONFIG ─────────────────────────────────────────────
ES_PATIENCE      = 5        # Rounds tanpa improvement sebelum stop
ES_MIN_DELTA     = 1e-4     # Minimum val_loss improvement untuk dianggap 'improvement'
es_best_val_loss = float('inf')
es_best_weights  = None
es_patience_counter = 0
es_stopped_round = None

print(f"Early Stopping: PATIENCE={ES_PATIENCE}, MIN_DELTA={ES_MIN_DELTA}")
print("Status: Ready.")
# Out:
# Early Stopping: PATIENCE=5, MIN_DELTA=0.0001
# Status: Ready.

# %%
gm = build_model(stage=1)
gm.compile(optimizer=keras.optimizers.Adam(LR),
            loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
gw = gm.get_weights(); del gm; tf.keras.backend.clear_session(); gc.collect()

fl_logs = []
print("="*60)
print(f"  Noise-Aware FedAvg | {FL_ROUNDS} rounds × {LOCAL_EPOCHS} local epochs")
print(f"  Noisy clients: {NOISY_CLIENTS}")
print("="*60)

for rnd in tqdm(range(1, FL_ROUNDS+1), desc="FL Rounds"):
    t0 = time.time()
    stage = 1 if rnd <= STAGE1_ROUNDS else 2
    print(f"\n[Round {rnd:02d}/{FL_ROUNDS}] Stage {stage}")

    client_ws, client_logs = [], []
    for ci,(cname,cX,cy,cw) in enumerate(zip(CLIENT_NAMES,Xtr,ytr,cws)):
        cw_,loss,acc,tag = local_train(gw,cX,cy,cw, cname,stage,seed=SEED+rnd)
        client_ws.append(cw_)
        client_logs.append({"client":cname,"stage":stage,"loss":loss,"accuracy":acc,"n":int(csz[ci])})
        print(f"  ✓ {cname:<8} {tag} loss:{loss:.4f}  acc:{acc:.4f}  n:{csz[ci]:,}")

    gw = fedavg(client_ws, csz)

    gm = build_model(stage)
    gm.set_weights(gw)
    gm.compile(optimizer=keras.optimizers.Adam(LR),
                loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
    vl,va = gm.evaluate(val_ds, verbose=0)
    elapsed = time.time()-t0
    print(f"  ▶ Val loss:{vl:.4f}  acc:{va:.4f}  ({elapsed:.1f}s)")

    # ── EARLY STOPPING CHECK ──────────────────────────────────────────────
    if vl < es_best_val_loss - ES_MIN_DELTA:
        es_best_val_loss = vl
        es_patience_counter = 0
        es_best_weights = gm.get_weights()  # Save best weights
        print(f"     ✓ BEST val_loss: {vl:.4f} (patience reset)")
    else:
        es_patience_counter += 1
        print(f"     ⚠ No improvement (patience {es_patience_counter}/{ES_PATIENCE})")
        if es_patience_counter >= ES_PATIENCE:
            print(f"\n  !! EARLY STOPPING TRIGGERED at round {rnd} !!")
            es_stopped_round = rnd
            break

    fl_logs.append({"round":rnd,"stage":stage,"val_loss":float(vl),"val_accuracy":float(va),
                    "time_sec":round(elapsed,2),"clients":client_logs})
    gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_round{rnd:02d}.keras")
    del client_ws; gc.collect()

print("\n"+"="*60+"\n  FL TRAINING COMPLETE\n"+"="*60)
gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_final.keras")
pd.DataFrame([{"round":r["round"],"stage":r["stage"],"val_acc":r["val_accuracy"],
               "val_loss":r["val_loss"],"time_sec":r["time_sec"]} for r in fl_logs]
).to_csv(f"{LOG_DIR}/fl_round_summary.csv",index=False)
print("Round logs saved.")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ============================================================
#   Noise-Aware FedAvg | 60 rounds × 2 local epochs
#   Noisy clients: ['DDR', 'EyePACS', 'APTOS']
# ============================================================
# FL Rounds:   0%|          | 0/60 [00:00<?, ?it/s]
# [Round 01/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6643  acc:0.2184  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6510  acc:0.2120  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6903  acc:0.1900  n:1,300
#   ▶ Val loss:1.5503  acc:0.2673  (237.3s)
#      ✓ BEST val_loss: 1.5503 (patience reset)
#
# [Round 02/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6065  acc:0.2670  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6299  acc:0.2304  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6709  acc:0.2038  n:1,300
#   ▶ Val loss:1.4858  acc:0.3454  (165.6s)
#      ✓ BEST val_loss: 1.4858 (patience reset)
#
# [Round 03/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5932  acc:0.2632  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6051  acc:0.2396  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6267  acc:0.2423  n:1,300
#   ▶ Val loss:1.4560  acc:0.3562  (168.5s)
#      ✓ BEST val_loss: 1.4560 (patience reset)
#
# [Round 04/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5523  acc:0.3023  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5856  acc:0.2494  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5989  acc:0.2600  n:1,300
#   ▶ Val loss:1.4183  acc:0.3849  (168.1s)
#      ✓ BEST val_loss: 1.4183 (patience reset)
#
# [Round 05/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5597  acc:0.2931  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5960  acc:0.2386  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5772  acc:0.2577  n:1,300
#   ▶ Val loss:1.4090  acc:0.3845  (173.3s)
#      ✓ BEST val_loss: 1.4090 (patience reset)
#
# [Round 06/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5326  acc:0.3031  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5584  acc:0.2577  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5828  acc:0.2654  n:1,300
#   ▶ Val loss:1.3902  acc:0.4019  (171.5s)
#      ✓ BEST val_loss: 1.3902 (patience reset)
#
# [Round 07/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5359  acc:0.3019  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5585  acc:0.2559  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5943  acc:0.2715  n:1,300
#   ▶ Val loss:1.3731  acc:0.3958  (173.9s)
#      ✓ BEST val_loss: 1.3731 (patience reset)
#
# [Round 08/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5204  acc:0.3054  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5517  acc:0.2584  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5625  acc:0.2723  n:1,300
#   ▶ Val loss:1.3725  acc:0.3920  (173.1s)
#      ✓ BEST val_loss: 1.3725 (patience reset)
#
# [Round 09/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5230  acc:0.2893  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5369  acc:0.2544  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5462  acc:0.3000  n:1,300
#   ▶ Val loss:1.3596  acc:0.4151  (175.0s)
#      ✓ BEST val_loss: 1.3596 (patience reset)
#
# [Round 10/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5000  acc:0.3215  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5388  acc:0.2586  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5249  acc:0.3138  n:1,300
#   ▶ Val loss:1.3489  acc:0.4240  (175.4s)
#      ✓ BEST val_loss: 1.3489 (patience reset)
#
# [Round 11/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4939  acc:0.3261  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5261  acc:0.2737  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5460  acc:0.2862  n:1,300
#   ▶ Val loss:1.3432  acc:0.4231  (176.6s)
#      ✓ BEST val_loss: 1.3432 (patience reset)
#
# [Round 12/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4869  acc:0.3234  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5436  acc:0.2629  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4922  acc:0.3262  n:1,300
#   ▶ Val loss:1.3401  acc:0.4245  (178.9s)
#      ✓ BEST val_loss: 1.3401 (patience reset)
#
# [Round 13/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4994  acc:0.3188  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5253  acc:0.2746  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5229  acc:0.3000  n:1,300
#   ▶ Val loss:1.3407  acc:0.4198  (181.0s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 14/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4838  acc:0.3410  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5240  acc:0.2767  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4865  acc:0.3354  n:1,300
#   ▶ Val loss:1.3334  acc:0.4155  (180.4s)
#      ✓ BEST val_loss: 1.3334 (patience reset)
#
# [Round 15/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4739  acc:0.3375  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5290  acc:0.2686  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5154  acc:0.2900  n:1,300
#   ▶ Val loss:1.3282  acc:0.4395  (179.8s)
#      ✓ BEST val_loss: 1.3282 (patience reset)
#
# [Round 16/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4516  acc:0.3648  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5014  acc:0.2832  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4852  acc:0.3008  n:1,300
#   ▶ Val loss:1.3226  acc:0.4329  (181.6s)
#      ✓ BEST val_loss: 1.3226 (patience reset)
#
# [Round 17/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4624  acc:0.3395  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4920  acc:0.2837  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5050  acc:0.3069  n:1,300
#   ▶ Val loss:1.3170  acc:0.4353  (184.5s)
#      ✓ BEST val_loss: 1.3170 (patience reset)
#
# [Round 18/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4688  acc:0.3326  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4963  acc:0.2854  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4970  acc:0.3138  n:1,300
#   ▶ Val loss:1.3245  acc:0.4259  (184.8s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 19/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4637  acc:0.3310  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5083  acc:0.2821  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4891  acc:0.3200  n:1,300
#   ▶ Val loss:1.3023  acc:0.4504  (186.3s)
#      ✓ BEST val_loss: 1.3023 (patience reset)
#
# [Round 20/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4887  acc:0.3249  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5013  acc:0.2849  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4549  acc:0.3562  n:1,300
#   ▶ Val loss:1.3115  acc:0.4358  (187.7s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 21/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4472  acc:0.3548  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5159  acc:0.2731  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4093  acc:0.3669  n:1,300
#   ▶ Val loss:1.3138  acc:0.4306  (188.5s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 22/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4503  acc:0.3544  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5099  acc:0.2691  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5089  acc:0.3054  n:1,300
#   ▶ Val loss:1.3082  acc:0.4409  (189.0s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 23/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4702  acc:0.3352  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5056  acc:0.2702  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4767  acc:0.3369  n:1,300
#   ▶ Val loss:1.3081  acc:0.4296  (193.9s)
#      ⚠ No improvement (patience 4/5)
#
# [Round 24/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4610  acc:0.3448  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5021  acc:0.2794  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4847  acc:0.3162  n:1,300
#   ▶ Val loss:1.3011  acc:0.4471  (191.4s)
#      ✓ BEST val_loss: 1.3011 (patience reset)
#
# [Round 25/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4722  acc:0.3387  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4980  acc:0.2789  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4649  acc:0.3446  n:1,300
#   ▶ Val loss:1.2939  acc:0.4475  (192.8s)
#      ✓ BEST val_loss: 1.2939 (patience reset)
#
# [Round 26/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4589  acc:0.3437  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5075  acc:0.2844  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4939  acc:0.3323  n:1,300
#   ▶ Val loss:1.3020  acc:0.4268  (195.5s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 27/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4428  acc:0.3498  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4880  acc:0.2899  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5044  acc:0.3077  n:1,300
#   ▶ Val loss:1.2955  acc:0.4414  (193.7s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 28/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4141  acc:0.3460  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4690  acc:0.2964  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3629  acc:0.4031  n:1,300
#   ▶ Val loss:1.2547  acc:0.4555  (205.4s)
#      ✓ BEST val_loss: 1.2547 (patience reset)
#
# [Round 29/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3605  acc:0.4015  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4668  acc:0.2849  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4170  acc:0.3954  n:1,300
#   ▶ Val loss:1.2317  acc:0.4588  (205.5s)
#      ✓ BEST val_loss: 1.2317 (patience reset)
#
# [Round 30/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3882  acc:0.3797  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4437  acc:0.3004  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3254  acc:0.4315  n:1,300
#   ▶ Val loss:1.2237  acc:0.4616  (206.0s)
#      ✓ BEST val_loss: 1.2237 (patience reset)
#
# [Round 31/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3577  acc:0.3835  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4333  acc:0.3027  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3493  acc:0.4092  n:1,300
#   ▶ Val loss:1.2292  acc:0.4395  (208.6s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 32/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3528  acc:0.3805  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4413  acc:0.3069  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3565  acc:0.4038  n:1,300
#   ▶ Val loss:1.2383  acc:0.4584  (212.3s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 33/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3663  acc:0.3797  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4063  acc:0.3295  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3100  acc:0.4423  n:1,300
#   ▶ Val loss:1.2392  acc:0.4612  (211.6s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 34/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3566  acc:0.4015  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4390  acc:0.3079  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2717  acc:0.4615  n:1,300
#   ▶ Val loss:1.2344  acc:0.4433  (209.2s)
#      ⚠ No improvement (patience 4/5)
#
# [Round 35/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3535  acc:0.3881  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4030  acc:0.3182  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3026  acc:0.4485  n:1,300
#   ▶ Val loss:1.1999  acc:0.4720  (210.7s)
#      ✓ BEST val_loss: 1.1999 (patience reset)
#
# [Round 36/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3704  acc:0.3874  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3971  acc:0.3268  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3365  acc:0.4446  n:1,300
#   ▶ Val loss:1.2043  acc:0.4809  (212.4s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 37/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3353  acc:0.3900  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4454  acc:0.3007  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3209  acc:0.4346  n:1,300
#   ▶ Val loss:1.2213  acc:0.4527  (215.1s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 38/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3159  acc:0.4249  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4103  acc:0.3178  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2743  acc:0.4692  n:1,300
#   ▶ Val loss:1.2189  acc:0.4682  (216.8s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 39/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3812  acc:0.3732  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4344  acc:0.3130  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4144  acc:0.3900  n:1,300
#   ▶ Val loss:1.1848  acc:0.4904  (217.2s)
#      ✓ BEST val_loss: 1.1848 (patience reset)
#
# [Round 40/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2574  acc:0.4490  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3934  acc:0.3338  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2543  acc:0.4738  n:1,300
#   ▶ Val loss:1.2015  acc:0.4805  (219.0s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 41/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3364  acc:0.4034  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4289  acc:0.3280  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3238  acc:0.4200  n:1,300
#   ▶ Val loss:1.1842  acc:0.4805  (218.8s)
#      ✓ BEST val_loss: 1.1842 (patience reset)
#
# [Round 42/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3844  acc:0.3716  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3642  acc:0.3500  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2284  acc:0.4908  n:1,300
#   ▶ Val loss:1.1731  acc:0.4908  (218.7s)
#      ✓ BEST val_loss: 1.1731 (patience reset)
#
# [Round 43/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3388  acc:0.3916  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3942  acc:0.3357  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2944  acc:0.4608  n:1,300
#   ▶ Val loss:1.2375  acc:0.4612  (222.2s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 44/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2796  acc:0.4418  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3589  acc:0.3500  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3148  acc:0.4392  n:1,300
#   ▶ Val loss:1.1827  acc:0.4852  (222.1s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 45/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3295  acc:0.3923  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3590  acc:0.3437  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2859  acc:0.4569  n:1,300
#   ▶ Val loss:1.1965  acc:0.4772  (224.3s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 46/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2201  acc:0.4644  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3655  acc:0.3390  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2839  acc:0.4600  n:1,300
#   ▶ Val loss:1.1912  acc:0.4781  (222.0s)
#      ⚠ No improvement (patience 4/5)
#
# [Round 47/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2456  acc:0.4349  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3855  acc:0.3375  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3945  acc:0.3654  n:1,300
#   ▶ Val loss:1.1665  acc:0.4762  (224.5s)
#      ✓ BEST val_loss: 1.1665 (patience reset)
#
# [Round 48/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2441  acc:0.4410  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3681  acc:0.3435  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3766  acc:0.4154  n:1,300
#   ▶ Val loss:1.1827  acc:0.4776  (224.4s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 49/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2828  acc:0.4195  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3619  acc:0.3485  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2921  acc:0.4662  n:1,300
#   ▶ Val loss:1.1602  acc:0.4899  (226.8s)
#      ✓ BEST val_loss: 1.1602 (patience reset)
#
# [Round 50/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2253  acc:0.4506  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3745  acc:0.3457  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2450  acc:0.4892  n:1,300
#   ▶ Val loss:1.1671  acc:0.4861  (228.8s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 51/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3592  acc:0.3858  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3510  acc:0.3575  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.1654  acc:0.5200  n:1,300
#   ▶ Val loss:1.1903  acc:0.4668  (229.4s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 52/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3147  acc:0.4138  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3934  acc:0.3300  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3594  acc:0.4262  n:1,300
#   ▶ Val loss:1.1917  acc:0.4800  (234.6s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 53/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3156  acc:0.4180  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3576  acc:0.3457  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2676  acc:0.4754  n:1,300
#   ▶ Val loss:1.1576  acc:0.4974  (231.8s)
#      ✓ BEST val_loss: 1.1576 (patience reset)
#
# [Round 54/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2437  acc:0.4544  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3640  acc:0.3473  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3652  acc:0.4031  n:1,300
#   ▶ Val loss:1.1832  acc:0.4842  (234.7s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 55/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3053  acc:0.4207  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3716  acc:0.3335  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3023  acc:0.4369  n:1,300
#   ▶ Val loss:1.1815  acc:0.4936  (237.1s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 56/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2459  acc:0.4487  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3616  acc:0.3540  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2192  acc:0.4946  n:1,300
#   ▶ Val loss:1.1963  acc:0.4744  (234.4s)
#      ⚠ No improvement (patience 3/5)
#
# [Round 57/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3208  acc:0.4180  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3803  acc:0.3235  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2459  acc:0.4685  n:1,300
#   ▶ Val loss:1.1488  acc:0.4998  (239.6s)
#      ✓ BEST val_loss: 1.1488 (patience reset)
#
# [Round 58/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2795  acc:0.4103  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3027  acc:0.3733  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3121  acc:0.4308  n:1,300
#   ▶ Val loss:1.1685  acc:0.4885  (240.5s)
#      ⚠ No improvement (patience 1/5)
#
# [Round 59/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2795  acc:0.4349  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3775  acc:0.3398  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.1882  acc:0.5062  n:1,300
#   ▶ Val loss:1.2056  acc:0.4678  (239.1s)
#      ⚠ No improvement (patience 2/5)
#
# [Round 60/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2423  acc:0.4648  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3752  acc:0.3318  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.1953  acc:0.4731  n:1,300
#   ▶ Val loss:1.1599  acc:0.4866  (241.5s)
#      ⚠ No improvement (patience 3/5)
#
# ============================================================
#   FL TRAINING COMPLETE
# ============================================================
# Round logs saved.

# %% [markdown]
# ## 11. FL Training Curves

# %%
rounds=[r["round"] for r in fl_logs]; val_acc=[r["val_accuracy"] for r in fl_logs]
val_loss=[r["val_loss"] for r in fl_logs]
sb=next((r for r,s in zip(rounds,[r["stage"] for r in fl_logs]) if s==2),None)
fig,ax=plt.subplots(1,2,figsize=(13,5))
for a,data,title in [(ax[0],val_acc,"Val Accuracy"),(ax[1],val_loss,"Val Loss")]:
    a.plot(rounds,data,marker="o",color="#4CAF50",lw=2)
    if sb: a.axvline(sb-.5,color="gray",ls=":",lw=1.5,label="S1→S2"); a.legend()
    a.set_xlabel("Round"); a.set_ylabel(title); a.set_title(f"Noise-Aware FedAvg — {title}")
    a.grid(alpha=.3); a.set_xticks(rounds)
plt.suptitle(f"Noise-Aware FedAvg — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/fl_training_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 12. Predict Clean + Noisy

# %%
print("Predicting clean...")
yp_clean = gm.predict(test_clean, verbose=1); yd_clean = np.argmax(yp_clean,1)
print("Predicting noisy...")
yp_noisy = gm.predict(test_noisy, verbose=1); yd_noisy = np.argmax(yp_noisy,1)
# Out:
# Predicting clean...
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 28s 317ms/step
# Predicting noisy...
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %% [markdown]
# ## 13. Metrics + Robustness Drop

# %%
def metrics(yt,yp,yprob):
    a = accuracy_score(yt,yp)
    p,r,f,_ = precision_recall_fscore_support(yt,yp,average="macro",zero_division=0)
    yb = label_binarize(yt,classes=np.arange(NUM_CLASSES))
    try: au = roc_auc_score(yb,yprob,multi_class="ovr",average="macro")
    except: au = float("nan")
    q = cohen_kappa_score(yt,yp,weights="quadratic")
    return dict(accuracy=float(a),precision_macro=float(p),recall_macro=float(r),
                f1_macro=float(f),auc_roc=float(au),qwk=float(q))

MKEYS = ["accuracy","precision_macro","recall_macro","f1_macro","auc_roc","qwk"]
mc = metrics(y_test,yd_clean,yp_clean)
mn = metrics(y_test,yd_noisy,yp_noisy)
print(f"{'Metric':<18} {'Clean':>8} {'Noisy':>8} {'Drop':>8}"); print("-"*44)
rob = {}
for k in MKEYS:
    d=mc[k]-mn[k]; rob[f"drop_{k}"]=float(d)
    print(f"{k:<18} {mc[k]:>8.4f} {mn[k]:>8.4f} {d:>+8.4f}")
# Out:
# Metric                Clean    Noisy     Drop
# --------------------------------------------
# accuracy             0.5007   0.2656  +0.2351
# precision_macro      0.4897   0.3321  +0.1576
# recall_macro         0.5065   0.3155  +0.1910
# f1_macro             0.4941   0.2208  +0.2733
# auc_roc              0.8088   0.6777  +0.1310
# qwk                  0.6940   0.2015  +0.4925

# %% [markdown]
# ## 14. Per-Class Metrics

# %%
def per_class(yt,yp):
    p,r,f,s = precision_recall_fscore_support(yt,yp,labels=np.arange(NUM_CLASSES),zero_division=0)
    return pd.DataFrame({"class":np.arange(NUM_CLASSES),"name":CLASS_NAMES,
                          "precision":p,"recall":r,"f1":f,"support":s})
pc_c=per_class(y_test,yd_clean); pc_n=per_class(y_test,yd_noisy)
print("CLEAN:"); print(pc_c.to_string(index=False))
print("\nNOISY:"); print(pc_n.to_string(index=False))
pc_c.to_csv(f"{LOG_DIR}/per_class_clean.csv",index=False)
pc_n.to_csv(f"{LOG_DIR}/per_class_noisy.csv",index=False)
# Out:
# CLEAN:
#  class          name  precision   recall       f1  support
#      0         No DR   0.606928 0.590044 0.598367      683
#      1          Mild   0.389098 0.458980 0.421160      451
#      2      Moderate   0.451613 0.329412 0.380952      510
#      3        Severe   0.381526 0.487179 0.427928      195
#      4 Proliferative   0.619355 0.666667 0.642140      288
#
# NOISY:
#  class          name  precision   recall       f1  support
#      0         No DR   0.593472 0.292826 0.392157      683
#      1          Mild   0.378788 0.055432 0.096712      451
#      2      Moderate   0.337500 0.052941 0.091525      510
#      3        Severe   0.148760 0.276923 0.193548      195
#      4 Proliferative   0.202186 0.899306 0.330147      288

# %% [markdown]
# ## 15. Per-Client Breakdown

# %%
print(f"{'Client':<10} {'N':>5}  {'Acc_C':>7} {'Acc_N':>7} {'Drop':>7}  {'F1_C':>6} {'F1_N':>6}  {'QWK_C':>7} {'QWK_N':>7}")
print("-"*78)
pcc = {}
for cl in CLIENT_NAMES:
    m = src_test==cl
    if not m.any(): continue
    mc_=metrics(y_test[m],yd_clean[m],yp_clean[m])
    mn_=metrics(y_test[m],yd_noisy[m],yp_noisy[m])
    pcc[cl]={"n":int(m.sum()),"clean":mc_,"noisy":mn_}
    print(f"{cl:<10} {m.sum():>5,}  {mc_['accuracy']:>7.4f} {mn_['accuracy']:>7.4f} {mc_['accuracy']-mn_['accuracy']:>+7.4f}"
          f"  {mc_['f1_macro']:>6.4f} {mn_['f1_macro']:>6.4f}  {mc_['qwk']:>7.4f} {mn_['qwk']:>7.4f}")
# Out:
# Client         N    Acc_C   Acc_N    Drop    F1_C   F1_N    QWK_C   QWK_N
# ------------------------------------------------------------------------------
# DDR          560   0.5929  0.4143 +0.1786  0.5427 0.3078   0.7753  0.4404
# EyePACS    1,288   0.4596  0.1887 +0.2710  0.4690 0.1611   0.6104  0.1150
# APTOS        279   0.5054  0.3226 +0.1828  0.4846 0.3050   0.7638  0.3175

# %% [markdown]
# ## 16. Confusion Matrices

# %%
SN=["NoDR","Mild","Mod.","Sev.","Prol."]
model_ref = model if 'model' in dir() else gm
cm_c=confusion_matrix(y_test,yd_clean,labels=np.arange(NUM_CLASSES))
cm_n=confusion_matrix(y_test,yd_noisy,labels=np.arange(NUM_CLASSES))
fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,cm,title in [(ax[0],cm_c,"Clean"),(ax[1],cm_n,"Noisy")]:
    im=a.imshow(cm,cmap="Blues"); plt.colorbar(im,ax=a,fraction=.046)
    a.set_xticks(range(NUM_CLASSES)); a.set_yticks(range(NUM_CLASSES))
    a.set_xticklabels(SN,rotation=30,ha="right"); a.set_yticklabels(SN)
    th=cm.max()/2
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            a.text(j,i,str(cm[i,j]),ha="center",va="center",fontsize=9,color="white" if cm[i,j]>th else "black")
    a.set_xlabel("Predicted"); a.set_ylabel("True"); a.set_title(f"{EXPERIMENT_NAME} — {title}")
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/confusion_matrices.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 17. ROC Curves

# %%
yb=label_binarize(y_test,classes=np.arange(NUM_CLASSES))
COLS=plt.cm.tab10(np.linspace(0,1,NUM_CLASSES))
fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,yprob,title in [(ax[0],yp_clean,"Clean"),(ax[1],yp_noisy,"Noisy")]:
    for i in range(NUM_CLASSES):
        fpr,tpr,_=roc_curve(yb[:,i],yprob[:,i])
        a.plot(fpr,tpr,color=COLS[i],lw=1.8,label=f"{CLASS_NAMES[i]} (AUC={auc(fpr,tpr):.3f})")
    a.plot([0,1],[0,1],"k--",lw=1); a.set_xlabel("FPR"); a.set_ylabel("TPR")
    a.set_title(f"{EXPERIMENT_NAME} ROC — {title}"); a.legend(fontsize=9,loc="lower right"); a.grid(alpha=.3)
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/roc_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 18. Robustness Drop Visualization

# %%
MLABELS=["Accuracy","Precision","Recall","F1","AUC-ROC","QWK"]
cv=[mc[k] for k in MKEYS]; nv=[mn[k] for k in MKEYS]; dv=[rob[f"drop_{k}"] for k in MKEYS]
x=np.arange(len(MLABELS)); w=.35
fig,ax=plt.subplots(1,2,figsize=(13,5))
ax[0].bar(x-w/2,cv,w,label="Clean",color="#4CAF50",alpha=.85)
ax[0].bar(x+w/2,nv,w,label="Noisy",color="#E53935",alpha=.85)
for i,(a_,b_) in enumerate(zip(cv,nv)):
    ax[0].text(i-w/2,a_+.01,f"{a_:.3f}",ha="center",fontsize=8)
    ax[0].text(i+w/2,b_+.01,f"{b_:.3f}",ha="center",fontsize=8)
ax[0].set_xticks(x); ax[0].set_xticklabels(MLABELS); ax[0].set_ylim(0,1.1)
ax[0].set_title("Clean vs Noisy"); ax[0].legend(); ax[0].grid(axis="y",alpha=.3)
clrs=["#4CAF50" if d<=.05 else "#FFC107" if d<=.1 else "#F44336" for d in dv]
ax[1].bar(x,dv,color=clrs,alpha=.85,edgecolor="black",lw=.5)
for i,d in enumerate(dv): ax[1].text(i,d+.003,f"{d:+.3f}",ha="center",fontsize=9,fontweight="bold")
ax[1].set_xticks(x); ax[1].set_xticklabels(MLABELS)
ax[1].set_title("Robustness Drop (↓ = lebih robust)"); ax[1].axhline(0,color="k",lw=.8,ls="--"); ax[1].grid(axis="y",alpha=.3)
plt.suptitle(f"{EXPERIMENT_NAME} — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/robustness_drop.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 19. Save Results + Summary

# %%
res={
    "experiment":EXPERIMENT_NAME,"model":MODEL_NAME,"paradigm":"Noise-Aware FedAvg",
    "use_noise_aug":USE_NOISE_AUG,"noisy_clients":NOISY_CLIENTS,
    "client_sizes":dict(zip(CLIENT_NAMES,[int(s) for s in csz])),
    "n_test":int(len(y_test)),
    "metrics_clean":mc,"metrics_noisy":mn,"robustness_drop":rob,"per_client":pcc,
    "confusion_matrix_clean":cm_c.tolist(),"confusion_matrix_noisy":cm_n.tolist(),
    "config": {
    "seed": SEED,
    "noisy_test_seed": NOISY_TEST_SEED,
    "batch": BATCH_SIZE,
    "lr": LR,
    "fl_rounds": FL_ROUNDS,
    "local_epochs": LOCAL_EPOCHS,
    "stage1_rounds": STAGE1_ROUNDS,
    "unfreeze_n": UNFREEZE_N,
    "noise_prob": NOISE_PROB,
    "blur_prob": BLUR_PROB,
    "bright_prob": BRIGHT_PROB,
}
}
with open(f"{LOG_DIR}/results.json","w") as f: json.dump(res,f,indent=2)
row={"experiment":EXPERIMENT_NAME,"paradigm":"Noise-Aware FedAvg","model":MODEL_NAME}
row.update({f"clean_{k}":mc[k] for k in MKEYS})
row.update({f"noisy_{k}":mn[k] for k in MKEYS})
row.update(rob)
pd.DataFrame([row]).to_csv(f"{LOG_DIR}/summary_row.csv",index=False)
print(f"Saved to: {RES}")
print("\n"+"="*60)
print(f"  EXP3 NOISE AWARE FL — DONE")
print("="*60)
print(f"  CLEAN  | Acc:{mc['accuracy']:.4f}  F1:{mc['f1_macro']:.4f}  AUC:{mc['auc_roc']:.4f}  QWK:{mc['qwk']:.4f}")
print(f"  NOISY  | Acc:{mn['accuracy']:.4f}  F1:{mn['f1_macro']:.4f}  AUC:{mn['auc_roc']:.4f}  QWK:{mn['qwk']:.4f}")
print(f"  DROP   | Acc:{rob['drop_accuracy']:+.4f}  F1:{rob['drop_f1_macro']:+.4f}  AUC:{rob['drop_auc_roc']:+.4f}  QWK:{rob['drop_qwk']:+.4f}")
print("="*60)
# Out:
# Saved to: /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/EfficientNetB0/exp3_noise_aware_fl
#
# ============================================================
#   EXP3 NOISE AWARE FL — DONE
# ============================================================
#   CLEAN  | Acc:0.5007  F1:0.4941  AUC:0.8088  QWK:0.6940
#   NOISY  | Acc:0.2656  F1:0.2208  AUC:0.6777  QWK:0.2015
#   DROP   | Acc:+0.2351  F1:+0.2733  AUC:+0.1310  QWK:+0.4925
# ============================================================

# %%
# ── AUTO SHUTDOWN RUNTIME (Colab) ────────────────────────────────
import time

print("Training selesai. Runtime akan shutdown dalam 60 detik...")
print("Tekan Ctrl+C untuk batalkan.")

try:
    for i in range(60, 0, -5):
        print(f"  Shutdown dalam {i} detik...")
        time.sleep(5)
    from google.colab import runtime
    runtime.unassign()
except KeyboardInterrupt:
    print("Shutdown dibatalkan.")
except Exception as e:
    print(f"Colab runtime unassign gagal: {e}")
    # Fallback
    import subprocess
    subprocess.run(["kill", "-9", "-1"], check=False)
# Out:
# Training selesai. Runtime akan shutdown dalam 60 detik...
# Tekan Ctrl+C untuk batalkan.
#   Shutdown dalam 60 detik...
#   Shutdown dalam 55 detik...
#   Shutdown dalam 50 detik...
#   Shutdown dalam 45 detik...
#   Shutdown dalam 40 detik...
#   Shutdown dalam 35 detik...
#   Shutdown dalam 30 detik...
#   Shutdown dalam 25 detik...
#   Shutdown dalam 20 detik...
#   Shutdown dalam 15 detik...
#   Shutdown dalam 10 detik...
#   Shutdown dalam 5 detik...
