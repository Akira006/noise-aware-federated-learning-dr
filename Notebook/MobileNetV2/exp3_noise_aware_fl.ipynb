# %% [markdown]
# <a href="https://colab.research.google.com/github/Akira006/noise-aware-federated-learning-dr/blob/main/Notebook/MobileNetV2/exp3_noise_aware_fl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 3 — Noise-Aware Federated Learning (Proposed Method)
# **Project:** Noise-Aware Federated Learning for Robust Diabetic Retinopathy Classification
# **Model:** MobileNetV2 | **Paradigm:** Noise-Aware FedAvg
#
# | Config | Value |
# |--------|-------|
# | Clients | DDR, EyePACS, APTOS |
# | Communication Rounds | 20 (rounds 1-10 frozen, 11-20 unfrozen) |
# | Local Epochs / Round | 5 |
# | Noise aug (training) | ✅ Stochastic (50% prob tiap jenis degradasi, semua client) |
# | Aggregation | Dataset-size-weighted FedAvg |
# | Test | Clean + Noisy (seed=123, identik di 3 notebook) |
#
# **Key difference dari Exp2:** Setiap sample training di-augment secara stochastic on-the-fly.
# Tiap pass beda — mirip kondisi nyata di fasilitas low-resource.
#
# > ⚠️ **JANGAN ubah `SEED` dan `NOISY_TEST_SEED`** — harus konsisten di 3 notebook.

# %% [markdown]
# ## 1. GPU Check

# %%
# !nvidia-smi
# Out:
# Sat Jun  6 17:11:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             61W /  400W |   23291MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1067      C   /usr/bin/python3                       9918MiB |
# |    0   N/A  N/A           62033      C   /usr/bin/python3                      13354MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# Cell 1 — GPU Setup (taruh sebelum semua import)
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"  # lebih stable di G4/L4
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✓ GPU: {gpus[0].name}")
    print(f"✓ TF version: {tf.__version__}")
else:
    print("No GPU detected")
# Out:
# ✓ GPU: /physical_device:GPU:0
# ✓ TF version: 2.20.0

# %% [markdown]
# ## 2. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# GPU Memory Growth — prevent CUDA_ERROR_INVALID_HANDLE
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU memory growth enabled: {len(gpus)} GPU(s)")
# Out:
# GPU memory growth enabled: 1 GPU(s)

# %% [markdown]
# ## 3. Imports

# %%
import os, json, random, time, gc, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    confusion_matrix, accuracy_score,
    precision_recall_fscore_support,
    roc_auc_score, roc_curve, auc, cohen_kappa_score
)
from sklearn.preprocessing import label_binarize

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.applications import MobileNetV2

print("TF:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 4. Configuration

# %%
# ── REPRODUCIBILITY (sama di 3 notebook) ─────────────────────────
SEED             = 42
NOISY_TEST_SEED  = 123
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── MODEL & EXPERIMENT ────────────────────────────────────────────
MODEL_NAME       = "MobileNetV2"
EXPERIMENT_NAME  = "exp3_noise_aware_fl"

# ── TRAINING ──────────────────────────────────────────────────────
IMG_SIZE         = (224, 224)
NUM_CLASSES      = 5
BATCH_SIZE       = 32
LR               = 1e-4
UNFREEZE_N       = 10
DROPOUT          = 0.4
L2               = 1e-4
# ── FL CONFIG ─────────────────────────────────────────────────────
FL_ROUNDS        = 60
LOCAL_EPOCHS     = 2
STAGE1_ROUNDS    = 27
STAGE2_ROUNDS    = 33
CLIENT_NAMES     = ["DDR","EyePACS","APTOS"]
USE_NOISE_AUG    = True
NOISY_CLIENTS    = ["DDR","EyePACS","APTOS"]   # semua client — sesuai Fig 2c paper

# ── NOISE PARAMS (sesuai Draft Paper Section III.B) ───────────────
NS_MIN, NS_MAX   = 0.01, 0.05     # Gaussian noise sigma
BL_MIN, BL_MAX   = 1.0,  3.0     # Gaussian blur sigma
BR_DELTA         = 0.2            # Brightness delta
CT_LOW, CT_HIGH  = 0.7,  1.3     # Contrast range
NOISE_PROB       = 0.5            # Probability per degradation type
BLUR_PROB        = 0.5
BRIGHT_PROB      = 0.5

CLASS_NAMES  = ["No DR","Mild","Moderate","Severe","Proliferative"]

# ── PATHS ─────────────────────────────────────────────────────────
PROJECT  = "/content/drive/MyDrive/Binus/Semester_4/Research_Methodology"
DS_BASE  = "/content/drive/MyDrive/S-Class/Orion/OrionFL"
BALANCED_DIR = f"{DS_BASE}/balanced"

APTOS_NPZ  = f"{DS_BASE}/balanced/aptos_balanced.npz"
DDR_NPZ    = f"{DS_BASE}/balanced/ddr_balanced.npz"
EYE_NPZ    = f"{DS_BASE}/balanced/eyepacs_balanced.npz"

RES      = f"{PROJECT}/Result/{MODEL_NAME}/{EXPERIMENT_NAME}"
MDL_DIR  = f"{RES}/models"
LOG_DIR  = f"{RES}/logs"
FIG_DIR  = f"{RES}/figures"
for d in [MDL_DIR, LOG_DIR, FIG_DIR]: os.makedirs(d, exist_ok=True)

print(f"Model        : {MODEL_NAME}  |  Use noise aug: {USE_NOISE_AUG}")
print(f"Noisy clients: {NOISY_CLIENTS}")
print(f"FL rounds    : {FL_ROUNDS} ({STAGE1_ROUNDS} frozen + {STAGE2_ROUNDS} unfrozen)")
print(f"Results      : {RES}")
# Out:
# Model        : MobileNetV2  |  Use noise aug: True
# Noisy clients: ['DDR', 'EyePACS', 'APTOS']
# FL rounds    : 60 (27 frozen + 33 unfrozen)
# Results      : /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/MobileNetV2/exp3_noise_aware_fl

# %% [markdown]
# ## 5. Load & Split Per Client (70:15:15)

# %%
def to01(X):
    X = X.astype(np.float32)
    return X / 255.0 if X.max() > 1.0 else X

def split_dataset(X, y, seed=SEED):
    X_tr,X_tmp,y_tr,y_tmp = train_test_split(X,y,test_size=.30,random_state=seed,stratify=y)
    X_v,X_te,y_v,y_te     = train_test_split(X_tmp,y_tmp,test_size=.50,random_state=seed,stratify=y_tmp)
    return X_tr,X_v,X_te,y_tr,y_v,y_te

# ── DDR ───────────────────────────────────────────────────────────
print("Loading DDR...")
d = np.load(DDR_NPZ, allow_pickle=True)
_img_key = "X" if "X" in d.files else "images"
_lbl_key = "y" if "y" in d.files else "labels"
X_ddr, y_ddr = to01(d[_img_key]), d[_lbl_key].astype(np.int64)
print(f"  keys used: images='{_img_key}', labels='{_lbl_key}' | shape={X_ddr.shape}")

# ── EyePACS ───────────────────────────────────────────────────────
print("Loading EyePACS...")
d = np.load(EYE_NPZ, allow_pickle=True)
X_eye = to01(d["images"])
if "labels" in d.files:
    y_eye = d["labels"].astype(np.int64)
    print(f"  label source: NPZ internal | shape={X_eye.shape}")
else:
    y_eye = pd.read_csv(EYE_CSV)["level"].values.astype(np.int64)
    print(f"  label source: CSV | shape={X_eye.shape}")
assert len(X_eye) == len(y_eye), f"Mismatch: {len(X_eye)} vs {len(y_eye)}"

# ── APTOS ─────────────────────────────────────────────────────────
print("Loading APTOS...")
d = np.load(APTOS_NPZ, allow_pickle=True)
X_apt, y_apt = to01(d["images"]), d["labels"].astype(np.int64)
print(f"  shape={X_apt.shape}")

# ── Split & Assign ────────────────────────────────────────────────
Xtr_d,Xv_d,Xte_d,ytr_d,yv_d,yte_d = split_dataset(X_ddr, y_ddr)
Xtr_e,Xv_e,Xte_e,ytr_e,yv_e,yte_e = split_dataset(X_eye, y_eye)
Xtr_a,Xv_a,Xte_a,ytr_a,yv_a,yte_a = split_dataset(X_apt, y_apt)
del X_ddr, X_eye, X_apt; gc.collect()

Xtr = [Xtr_d, Xtr_e, Xtr_a]
ytr = [ytr_d, ytr_e, ytr_a]
csz = [len(ytr_d), len(ytr_e), len(ytr_a)]

X_val    = np.concatenate([Xv_d,  Xv_e,  Xv_a])
y_val    = np.concatenate([yv_d,  yv_e,  yv_a])
X_test   = np.concatenate([Xte_d, Xte_e, Xte_a])
y_test   = np.concatenate([yte_d, yte_e, yte_a])
src_test = np.array(["DDR"]*len(yte_d)+["EyePACS"]*len(yte_e)+["APTOS"]*len(yte_a))

print(f"\nClient sizes : {dict(zip(CLIENT_NAMES, csz))}")
print(f"Val          : {len(y_val):,}")
print(f"Test         : {len(y_test):,}")
for name, y in zip(CLIENT_NAMES, ytr):
    dist = dict(zip(*np.unique(y, return_counts=True)))
    print(f"  {name} dist : {dist}")
# Out:
# Loading DDR...
#   keys used: images='images', labels='labels' | shape=(3729, 224, 224, 3)
# Loading EyePACS...
#   label source: NPZ internal | shape=(8581, 224, 224, 3)
# Loading APTOS...
#   shape=(1858, 224, 224, 3)
#
# Client sizes : {'DDR': 2610, 'EyePACS': 6006, 'APTOS': 1300}
# Val          : 2,125
# Test         : 2,127
#   DDR dist : {np.int64(0): np.int64(735), np.int64(1): np.int64(441), np.int64(2): np.int64(630), np.int64(3): np.int64(165), np.int64(4): np.int64(639)}
#   EyePACS dist : {np.int64(0): np.int64(2100), np.int64(1): np.int64(1400), np.int64(2): np.int64(1400), np.int64(3): np.int64(611), np.int64(4): np.int64(495)}
#   APTOS dist : {np.int64(0): np.int64(350), np.int64(1): np.int64(259), np.int64(2): np.int64(350), np.int64(3): np.int64(135), np.int64(4): np.int64(206)}

# %% [markdown]
# ## 6. Per-Client Class Weights

# %%
def get_cw(y):
    cls = np.unique(y)
    cw  = compute_class_weight("balanced", classes=cls, y=y)
    d   = {int(c):float(w) for c,w in zip(cls,cw)}
    for c in range(NUM_CLASSES): d.setdefault(c, 1.0)
    return d

cws = [get_cw(y) for y in ytr]
for name,cw in zip(CLIENT_NAMES,cws): print(f"{name}: {cw}")
# Out:
# DDR: {0: 0.710204081632653, 1: 1.183673469387755, 2: 0.8285714285714286, 3: 3.1636363636363636, 4: 0.8169014084507042}
# EyePACS: {0: 0.572, 1: 0.858, 2: 0.858, 3: 1.9659574468085106, 4: 2.4266666666666667}
# APTOS: {0: 0.7428571428571429, 1: 1.0038610038610039, 2: 0.7428571428571429, 3: 1.9259259259259258, 4: 1.2621359223300972}

# %% [markdown]
# ## 7. Noise Pipeline
#
# Dua mode:
# - **Stochastic** (training): probabilistic per degradation, fresh rng tiap sample
# - **Deterministic** (test set): always-apply semua jenis, seeded → reproducible

# %%
def gauss_noise(img, sigma):
    return np.clip(img + np.random.normal(0, sigma, img.shape).astype(np.float32), 0, 1)

def gauss_blur(img, sigma):
    out = np.empty_like(img)
    for ch in range(img.shape[2]):
        out[:, :, ch] = gaussian_filter(img[:, :, ch], sigma=sigma)
    return np.clip(out.astype(np.float32), 0, 1)

def bright_contrast(img, bd, cf):
    m = img.mean()
    return np.clip(((img - m) * cf + m + bd).astype(np.float32), 0, 1)

def stochastic_degrade(img):
    rng = np.random.default_rng()
    img = img.copy()
    if rng.random() < NOISE_PROB:  img = gauss_noise(img,     rng.uniform(NS_MIN, NS_MAX))
    if rng.random() < BLUR_PROB:   img = gauss_blur(img,      rng.uniform(BL_MIN, BL_MAX))
    if rng.random() < BRIGHT_PROB: img = bright_contrast(img, rng.uniform(-BR_DELTA, BR_DELTA), rng.uniform(CT_LOW, CT_HIGH))
    return img

def deterministic_degrade(img, rng):
    img = img.copy()
    img = gauss_noise(img,     rng.uniform(NS_MIN, NS_MAX))
    img = gauss_blur(img,      rng.uniform(BL_MIN, BL_MAX))
    img = bright_contrast(img, rng.uniform(-BR_DELTA, BR_DELTA), rng.uniform(CT_LOW, CT_HIGH))
    return img

def make_noisy_set(X, seed=NOISY_TEST_SEED):
    print(f"  Generating noisy test set (n={len(X)}, seed={seed})...")
    rng = np.random.default_rng(seed)
    out = np.empty_like(X)
    for i in range(len(X)): out[i] = deterministic_degrade(X[i], rng)
    print(f"  Done. range=[{out.min():.3f},{out.max():.3f}]")
    return out

X_test_noisy = make_noisy_set(X_test)
# Out:
#   Generating noisy test set (n=2127, seed=123)...
#   Done. range=[0.000,1.000]

# %% [markdown]
# ## 8. Visualize Stochastic Augmentation

# %%
sample = Xtr[0][0]
fig, axes = plt.subplots(1,5,figsize=(16,4))
axes[0].imshow(sample); axes[0].set_title("Original"); axes[0].axis("off")
for i in range(4):
    aug = stochastic_degrade(sample)
    axes[i+1].imshow(aug); axes[i+1].set_title(f"Aug #{i+1}"); axes[i+1].axis("off")
plt.suptitle("Stochastic Aug — 4 different realizations of same image", fontweight="bold")
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/stochastic_aug_preview.png", dpi=150, bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 9. Model Builder + TF Dataset Helpers

# %%
AUT = tf.data.AUTOTUNE

def make_ds(X, y, shuffle=False, seed=None):
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).prefetch(AUT)

def make_noisy_train_ds(X, y, shuffle=True, seed=None):
    """Training dataset with on-the-fly stochastic augmentation."""
    def tf_aug(x, label):
        def np_aug(img_np):
            return stochastic_degrade(img_np.numpy()).astype(np.float32)
        x_aug = tf.py_function(np_aug, [x], tf.float32)
        x_aug.set_shape(x.shape)   # prevent shape=None crash
        return x_aug, label
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).map(tf_aug, num_parallel_calls=AUT).prefetch(AUT)

def build_model(stage=1):
    base = MobileNetV2(include_top=False, weights="imagenet", input_shape=(224,224,3))
    base.trainable = False
    if stage == 2:
        base.trainable = True
        for l in base.layers[:-UNFREEZE_N]: l.trainable = False
        for l in base.layers[-UNFREEZE_N:]: l.trainable = True
        for l in base.layers:
            if isinstance(l, layers.BatchNormalization): l.trainable = False
    inp = keras.Input((224,224,3))
    x   = base(inp, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dropout(DROPOUT)(x)
    out = layers.Dense(NUM_CLASSES, activation="softmax",
                       kernel_regularizer=regularizers.l2(L2))(x)
    return keras.Model(inp, out)

def fedavg(weights_list, sizes):
    total = sum(sizes)
    return [np.sum([weights_list[i][li]*(sizes[i]/total) for i in range(len(sizes))],axis=0)
            for li in range(len(weights_list[0]))]

# Eval datasets (always clean)
val_ds     = make_ds(X_val, y_val)
test_clean = make_ds(X_test, y_test)
test_noisy = make_ds(X_test_noisy, y_test)
print("Model + dataset helpers ready.")
# Out:
# Model + dataset helpers ready.

# %% [markdown]
# ## 10. Local Training Function
#
# Clients di `NOISY_CLIENTS` → training pakai **stochastic noisy dataset**.
# Clients lain → clean dataset.
# Eksperimen ini: semua 3 client masuk `NOISY_CLIENTS` (sesuai Fig 2c paper).

# %%
def local_train(global_w, X, y, cw, client_name, stage, seed):
    m = build_model(stage)
    m.set_weights(global_w)
    m.compile(optimizer=keras.optimizers.Adam(LR),
               loss=keras.losses.SparseCategoricalCrossentropy(),
               metrics=["accuracy"])

    # Conditional noise application
    if client_name in NOISY_CLIENTS:
        ds  = make_noisy_train_ds(X, y, shuffle=True, seed=seed)
        tag = "[+NOISE]"
    else:
        ds  = make_ds(X, y, shuffle=True, seed=seed)
        tag = "[clean]"

    h   = m.fit(ds, epochs=LOCAL_EPOCHS, class_weight=cw, verbose=0)
    w, loss, acc = m.get_weights(), h.history["loss"][-1], h.history["accuracy"][-1]
    del m, ds; tf.keras.backend.clear_session(); gc.collect()
    return w, float(loss), float(acc), tag

print("local_train (noise-aware) ready.")
# Out:
# local_train (noise-aware) ready.

# %% [markdown]
# ## 11. FL Training Loop — Noise-Aware FedAvg

# %%
gm = build_model(stage=1)
gm.compile(optimizer=keras.optimizers.Adam(LR),
            loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
gw = gm.get_weights(); del gm; tf.keras.backend.clear_session(); gc.collect()

fl_logs = []
print("="*65)
print(f"  Noise-Aware FedAvg | {FL_ROUNDS} rounds × {LOCAL_EPOCHS} local epochs")
print(f"  Noisy clients: {NOISY_CLIENTS}")
print(f"  Stage 1: rounds 1-{STAGE1_ROUNDS} | Stage 2: rounds {STAGE1_ROUNDS+1}-{FL_ROUNDS}")
print("="*65)

for rnd in tqdm(range(1, FL_ROUNDS+1), desc="FL Rounds"):
    t0    = time.time()
    stage = 1 if rnd <= STAGE1_ROUNDS else 2
    print(f"\n[Round {rnd:02d}/{FL_ROUNDS}] Stage {stage}")

    client_ws, client_logs = [], []
    for ci,(cname,cX,cy,cw) in enumerate(zip(CLIENT_NAMES,Xtr,ytr,cws)):
        cw_,loss,acc,tag = local_train(gw,cX,cy,cw,cname,stage,seed=SEED+rnd)
        client_ws.append(cw_)
        client_logs.append({"client":cname,"stage":stage,"noise":cname in NOISY_CLIENTS,
                             "loss":loss,"accuracy":acc,"n":int(csz[ci])})
        print(f"  ✓ {cname:<8} {tag} loss:{loss:.4f}  acc:{acc:.4f}  n:{csz[ci]:,}")

    gw = fedavg(client_ws, csz)

    gm = build_model(stage)
    gm.set_weights(gw)
    gm.compile(optimizer=keras.optimizers.Adam(LR),
                loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
    vl, va = gm.evaluate(val_ds, verbose=0)
    elapsed = time.time()-t0
    print(f"  ▶ Val loss:{vl:.4f}  acc:{va:.4f}  ({elapsed:.1f}s)")

    fl_logs.append({"round":rnd,"stage":stage,"val_loss":float(vl),"val_accuracy":float(va),
                    "time_sec":round(elapsed,2),"clients":client_logs})

    gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_round{rnd:02d}.keras")
    del client_ws; gc.collect()

print("\n"+"="*65+"\n  FL TRAINING COMPLETE\n"+"="*65)
gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_final.keras")

pd.DataFrame([{"round":r["round"],"stage":r["stage"],"val_acc":r["val_accuracy"],
               "val_loss":r["val_loss"],"time_sec":r["time_sec"]} for r in fl_logs]
).to_csv(f"{LOG_DIR}/fl_round_summary.csv",index=False)
print(f"Round logs saved.")
# Out:
# =================================================================
#   Noise-Aware FedAvg | 60 rounds × 2 local epochs
#   Noisy clients: ['DDR', 'EyePACS', 'APTOS']
#   Stage 1: rounds 1-27 | Stage 2: rounds 28-60
# =================================================================
# FL Rounds:   0%|          | 0/60 [00:00<?, ?it/s]
# [Round 01/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.8510  acc:0.2130  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.8741  acc:0.2131  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.9549  acc:0.1992  n:1,300
#   ▶ Val loss:1.5786  acc:0.2659  (197.1s)
#
# [Round 02/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.7704  acc:0.2322  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.8018  acc:0.2258  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.8385  acc:0.2300  n:1,300
#   ▶ Val loss:1.5015  acc:0.3224  (121.3s)
#
# [Round 03/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6973  acc:0.2697  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.7455  acc:0.2334  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.7312  acc:0.2585  n:1,300
#   ▶ Val loss:1.4828  acc:0.3271  (126.2s)
#
# [Round 04/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.7289  acc:0.2498  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.7333  acc:0.2484  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.7278  acc:0.2585  n:1,300
#   ▶ Val loss:1.4416  acc:0.3539  (121.3s)
#
# [Round 05/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6626  acc:0.2820  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.7061  acc:0.2346  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6407  acc:0.2877  n:1,300
#   ▶ Val loss:1.4466  acc:0.3539  (121.0s)
#
# [Round 06/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6550  acc:0.2674  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6721  acc:0.2448  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.7390  acc:0.2562  n:1,300
#   ▶ Val loss:1.4089  acc:0.3732  (125.6s)
#
# [Round 07/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6155  acc:0.2908  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6473  acc:0.2576  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6602  acc:0.2915  n:1,300
#   ▶ Val loss:1.3942  acc:0.3769  (128.5s)
#
# [Round 08/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5980  acc:0.2927  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6424  acc:0.2514  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6350  acc:0.2900  n:1,300
#   ▶ Val loss:1.3942  acc:0.3788  (125.5s)
#
# [Round 09/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5856  acc:0.3088  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6205  acc:0.2557  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6141  acc:0.3062  n:1,300
#   ▶ Val loss:1.3807  acc:0.3920  (124.6s)
#
# [Round 10/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5700  acc:0.3000  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6139  acc:0.2541  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6332  acc:0.2962  n:1,300
#   ▶ Val loss:1.3864  acc:0.3746  (126.7s)
#
# [Round 11/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5652  acc:0.2973  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5857  acc:0.2636  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6069  acc:0.2931  n:1,300
#   ▶ Val loss:1.3769  acc:0.3765  (129.9s)
#
# [Round 12/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5884  acc:0.2927  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6034  acc:0.2529  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.6109  acc:0.2854  n:1,300
#   ▶ Val loss:1.3659  acc:0.4014  (129.3s)
#
# [Round 13/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5580  acc:0.3130  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.6010  acc:0.2602  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5677  acc:0.3192  n:1,300
#   ▶ Val loss:1.3650  acc:0.4075  (131.3s)
#
# [Round 14/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5364  acc:0.3096  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5716  acc:0.2601  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5424  acc:0.3438  n:1,300
#   ▶ Val loss:1.3565  acc:0.3953  (127.8s)
#
# [Round 15/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5252  acc:0.3153  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5549  acc:0.2596  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5693  acc:0.3077  n:1,300
#   ▶ Val loss:1.3588  acc:0.4042  (127.1s)
#
# [Round 16/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5287  acc:0.3215  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5682  acc:0.2661  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5031  acc:0.3308  n:1,300
#   ▶ Val loss:1.3558  acc:0.4108  (131.7s)
#
# [Round 17/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5159  acc:0.3264  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5688  acc:0.2579  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5432  acc:0.3169  n:1,300
#   ▶ Val loss:1.3382  acc:0.4240  (128.4s)
#
# [Round 18/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5023  acc:0.3333  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5352  acc:0.2639  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4931  acc:0.3492  n:1,300
#   ▶ Val loss:1.3395  acc:0.4226  (124.3s)
#
# [Round 19/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5227  acc:0.3065  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5416  acc:0.2692  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5152  acc:0.3308  n:1,300
#   ▶ Val loss:1.3275  acc:0.4249  (124.1s)
#
# [Round 20/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4985  acc:0.3299  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5367  acc:0.2677  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5039  acc:0.3392  n:1,300
#   ▶ Val loss:1.3355  acc:0.4165  (125.6s)
#
# [Round 21/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4955  acc:0.3272  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5291  acc:0.2736  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4734  acc:0.3662  n:1,300
#   ▶ Val loss:1.3348  acc:0.4249  (123.9s)
#
# [Round 22/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4939  acc:0.3464  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5246  acc:0.2721  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5337  acc:0.3162  n:1,300
#   ▶ Val loss:1.3402  acc:0.4264  (125.4s)
#
# [Round 23/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4786  acc:0.3291  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5114  acc:0.2672  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4915  acc:0.3662  n:1,300
#   ▶ Val loss:1.3358  acc:0.4174  (123.9s)
#
# [Round 24/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4760  acc:0.3299  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5506  acc:0.2574  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.5055  acc:0.3300  n:1,300
#   ▶ Val loss:1.3378  acc:0.4198  (126.8s)
#
# [Round 25/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5079  acc:0.3096  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5171  acc:0.2684  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4875  acc:0.3431  n:1,300
#   ▶ Val loss:1.3289  acc:0.4165  (127.0s)
#
# [Round 26/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4808  acc:0.3337  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5159  acc:0.2677  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4759  acc:0.3500  n:1,300
#   ▶ Val loss:1.3334  acc:0.4174  (126.3s)
#
# [Round 27/60] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4731  acc:0.3257  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5077  acc:0.2824  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4861  acc:0.3492  n:1,300
#   ▶ Val loss:1.3223  acc:0.4235  (125.1s)
#
# [Round 28/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4544  acc:0.3418  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.5214  acc:0.2566  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4424  acc:0.3669  n:1,300
#   ▶ Val loss:1.4003  acc:0.3878  (137.6s)
#
# [Round 29/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4601  acc:0.3444  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4880  acc:0.2769  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3734  acc:0.4315  n:1,300
#   ▶ Val loss:1.4241  acc:0.3369  (132.8s)
#
# [Round 30/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4554  acc:0.3414  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4983  acc:0.2684  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4037  acc:0.4046  n:1,300
#   ▶ Val loss:1.3398  acc:0.4024  (132.9s)
#
# [Round 31/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3976  acc:0.3648  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4922  acc:0.2912  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4274  acc:0.3854  n:1,300
#   ▶ Val loss:1.3244  acc:0.4127  (132.2s)
#
# [Round 32/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3874  acc:0.3732  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4671  acc:0.2889  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4028  acc:0.4000  n:1,300
#   ▶ Val loss:1.3697  acc:0.3845  (130.9s)
#
# [Round 33/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3845  acc:0.3828  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4572  acc:0.2912  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3689  acc:0.4146  n:1,300
#   ▶ Val loss:1.3366  acc:0.4085  (134.9s)
#
# [Round 34/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3272  acc:0.4184  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4822  acc:0.2829  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3627  acc:0.3854  n:1,300
#   ▶ Val loss:1.3442  acc:0.4038  (134.3s)
#
# [Round 35/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3753  acc:0.3625  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4672  acc:0.2799  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3843  acc:0.3969  n:1,300
#   ▶ Val loss:1.3047  acc:0.4325  (133.8s)
#
# [Round 36/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3446  acc:0.3962  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4562  acc:0.3007  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3451  acc:0.4277  n:1,300
#   ▶ Val loss:1.3578  acc:0.4005  (135.7s)
#
# [Round 37/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3564  acc:0.3954  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4494  acc:0.3087  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2851  acc:0.4531  n:1,300
#   ▶ Val loss:1.2833  acc:0.4391  (135.6s)
#
# [Round 38/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3811  acc:0.4031  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4630  acc:0.2902  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2999  acc:0.4338  n:1,300
#   ▶ Val loss:1.3492  acc:0.4080  (134.9s)
#
# [Round 39/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3620  acc:0.3927  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4342  acc:0.3064  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2603  acc:0.4285  n:1,300
#   ▶ Val loss:1.3359  acc:0.4014  (135.8s)
#
# [Round 40/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3537  acc:0.3977  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3793  acc:0.3345  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.4427  acc:0.3854  n:1,300
#   ▶ Val loss:1.3018  acc:0.4367  (134.0s)
#
# [Round 41/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3285  acc:0.4226  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4518  acc:0.2990  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3738  acc:0.4069  n:1,300
#   ▶ Val loss:1.2845  acc:0.4344  (140.0s)
#
# [Round 42/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3394  acc:0.4107  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4442  acc:0.3065  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2948  acc:0.4415  n:1,300
#   ▶ Val loss:1.2986  acc:0.4334  (138.3s)
#
# [Round 43/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4302  acc:0.3556  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4176  acc:0.3223  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3601  acc:0.4054  n:1,300
#   ▶ Val loss:1.2936  acc:0.4127  (141.5s)
#
# [Round 44/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4105  acc:0.3517  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4275  acc:0.3157  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3334  acc:0.4338  n:1,300
#   ▶ Val loss:1.2880  acc:0.4414  (139.5s)
#
# [Round 45/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2967  acc:0.4215  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3670  acc:0.3462  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3457  acc:0.4292  n:1,300
#   ▶ Val loss:1.3302  acc:0.3981  (140.7s)
#
# [Round 46/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3362  acc:0.3877  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3929  acc:0.3300  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2663  acc:0.4746  n:1,300
#   ▶ Val loss:1.2980  acc:0.4320  (138.4s)
#
# [Round 47/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3671  acc:0.3785  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3929  acc:0.3195  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3494  acc:0.4285  n:1,300
#   ▶ Val loss:1.2917  acc:0.4461  (141.6s)
#
# [Round 48/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3456  acc:0.4092  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3834  acc:0.3383  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2927  acc:0.4469  n:1,300
#   ▶ Val loss:1.3013  acc:0.4188  (141.3s)
#
# [Round 49/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3574  acc:0.3912  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3888  acc:0.3313  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3003  acc:0.4523  n:1,300
#   ▶ Val loss:1.3895  acc:0.3694  (141.3s)
#
# [Round 50/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3289  acc:0.4169  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3731  acc:0.3375  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3596  acc:0.4046  n:1,300
#   ▶ Val loss:1.3062  acc:0.4047  (141.8s)
#
# [Round 51/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3564  acc:0.3954  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3805  acc:0.3308  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3183  acc:0.4315  n:1,300
#   ▶ Val loss:1.2908  acc:0.4174  (141.3s)
#
# [Round 52/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3057  acc:0.4249  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3953  acc:0.3265  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2970  acc:0.4677  n:1,300
#   ▶ Val loss:1.3803  acc:0.3769  (142.8s)
#
# [Round 53/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3755  acc:0.3739  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4037  acc:0.3330  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3549  acc:0.4200  n:1,300
#   ▶ Val loss:1.2596  acc:0.4593  (144.0s)
#
# [Round 54/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3952  acc:0.3943  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3575  acc:0.3571  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2746  acc:0.4408  n:1,300
#   ▶ Val loss:1.3616  acc:0.3981  (146.3s)
#
# [Round 55/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3434  acc:0.3923  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3446  acc:0.3591  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2212  acc:0.4731  n:1,300
#   ▶ Val loss:1.3080  acc:0.4184  (145.6s)
#
# [Round 56/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3364  acc:0.3943  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3573  acc:0.3423  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.1962  acc:0.4992  n:1,300
#   ▶ Val loss:1.3430  acc:0.4024  (144.5s)
#
# [Round 57/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3125  acc:0.4172  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3886  acc:0.3437  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2876  acc:0.4446  n:1,300
#   ▶ Val loss:1.2887  acc:0.4212  (148.0s)
#
# [Round 58/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2711  acc:0.4115  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3382  acc:0.3520  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3255  acc:0.4300  n:1,300
#   ▶ Val loss:1.2734  acc:0.4546  (146.9s)
#
# [Round 59/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2961  acc:0.4234  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.4068  acc:0.3198  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.3997  acc:0.3877  n:1,300
#   ▶ Val loss:1.3011  acc:0.4108  (147.5s)
#
# [Round 60/60] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3333  acc:0.4103  n:2,610
#   ✓ EyePACS  [+NOISE] loss:1.3353  acc:0.3490  n:6,006
#   ✓ APTOS    [+NOISE] loss:1.2811  acc:0.4477  n:1,300
#   ▶ Val loss:1.2998  acc:0.4362  (145.6s)
#
# =================================================================
#   FL TRAINING COMPLETE
# =================================================================
# Round logs saved.

# %% [markdown]
# ## 12. FL Training Curves

# %%
rounds   = [r["round"] for r in fl_logs]
val_acc  = [r["val_accuracy"] for r in fl_logs]
val_loss = [r["val_loss"] for r in fl_logs]
sb       = next((r for r,s in zip(rounds,[r["stage"] for r in fl_logs]) if s==2), None)

fig,ax = plt.subplots(1,2,figsize=(13,5))
for a,data,title in [(ax[0],val_acc,"Val Accuracy"),(ax[1],val_loss,"Val Loss")]:
    a.plot(rounds,data,marker="o",color="#4CAF50",lw=2)
    if sb: a.axvline(sb-.5,color="gray",ls=":",lw=1.5,label="S1→S2"); a.legend()
    a.set_xlabel("Round"); a.set_ylabel(title); a.set_title(f"Noise-Aware FedAvg — {title}")
    a.grid(alpha=.3); a.set_xticks(rounds)
plt.suptitle(f"Noise-Aware FedAvg — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/fl_training_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 13. Predict Clean + Noisy

# %%
print("Predicting clean...")
yp_clean = gm.predict(test_clean, verbose=1)
yd_clean = np.argmax(yp_clean,1)

print("Predicting noisy...")
yp_noisy = gm.predict(test_noisy, verbose=1)
yd_noisy = np.argmax(yp_noisy,1)
# Out:
# Predicting clean...
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 23s 270ms/step
# Predicting noisy...
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %% [markdown]
# ## 14. Metrics + Robustness Drop

# %%
def metrics(yt,yp,yprob):
    a = accuracy_score(yt,yp)
    p,r,f,_ = precision_recall_fscore_support(yt,yp,average="macro",zero_division=0)
    yb = label_binarize(yt,classes=np.arange(NUM_CLASSES))
    try: au = roc_auc_score(yb,yprob,multi_class="ovr",average="macro")
    except: au = float("nan")
    q = cohen_kappa_score(yt,yp,weights="quadratic")
    return dict(accuracy=float(a),precision_macro=float(p),recall_macro=float(r),
                f1_macro=float(f),auc_roc=float(au),qwk=float(q))

MKEYS = ["accuracy","precision_macro","recall_macro","f1_macro","auc_roc","qwk"]
mc = metrics(y_test,yd_clean,yp_clean)
mn = metrics(y_test,yd_noisy,yp_noisy)

print(f"{'Metric':<18} {'Clean':>8} {'Noisy':>8} {'Drop':>8}")
print("-"*44)
rob = {}
for k in MKEYS:
    d=mc[k]-mn[k]; rob[f"drop_{k}"]=float(d)
    print(f"{k:<18} {mc[k]:>8.4f} {mn[k]:>8.4f} {d:>+8.4f}")
# Out:
# Metric                Clean    Noisy     Drop
# --------------------------------------------
# accuracy             0.4368   0.2755  +0.1613
# precision_macro      0.4299   0.3207  +0.1092
# recall_macro         0.4541   0.3094  +0.1447
# f1_macro             0.4218   0.2260  +0.1958
# auc_roc              0.7628   0.6329  +0.1299
# qwk                  0.6069   0.2169  +0.3899

# %% [markdown]
# ## 15. Per-Class Metrics

# %%
def per_class(yt,yp):
    p,r,f,s = precision_recall_fscore_support(yt,yp,labels=np.arange(NUM_CLASSES),zero_division=0)
    return pd.DataFrame({"class":np.arange(NUM_CLASSES),"name":CLASS_NAMES,
                          "precision":p,"recall":r,"f1":f,"support":s})
pc_c=per_class(y_test,yd_clean); pc_n=per_class(y_test,yd_noisy)
print("CLEAN:"); print(pc_c.to_string(index=False))
print("\nNOISY:"); print(pc_n.to_string(index=False))
pc_c.to_csv(f"{LOG_DIR}/per_class_clean.csv",index=False)
pc_n.to_csv(f"{LOG_DIR}/per_class_noisy.csv",index=False)
# Out:
# CLEAN:
#  class          name  precision   recall       f1  support
#      0         No DR   0.544139 0.550512 0.547307      683
#      1          Mild   0.350000 0.450111 0.393792      451
#      2      Moderate   0.408163 0.156863 0.226629      510
#      3        Severe   0.289617 0.543590 0.377897      195
#      4 Proliferative   0.557823 0.569444 0.563574      288
#
# NOISY:
#  class          name  precision   recall       f1  support
#      0         No DR   0.441016 0.355783 0.393841      683
#      1          Mild   0.523810 0.024390 0.046610      451
#      2      Moderate   0.263158 0.098039 0.142857      510
#      3        Severe   0.147139 0.276923 0.192171      195
#      4 Proliferative   0.228457 0.791667 0.354588      288

# %% [markdown]
# ## 16. Per-Client Breakdown

# %%
print(f"{'Client':<10} {'N':>5}  {'Acc_C':>7} {'Acc_N':>7} {'Drop':>7}  {'F1_C':>6} {'F1_N':>6}  {'QWK_C':>7} {'QWK_N':>7}")
print("-"*78)
pcc = {}
for cl in CLIENT_NAMES:
    m = src_test==cl
    if not m.any(): continue
    mc_=metrics(y_test[m],yd_clean[m],yp_clean[m])
    mn_=metrics(y_test[m],yd_noisy[m],yp_noisy[m])
    pcc[cl]={"n":int(m.sum()),"clean":mc_,"noisy":mn_}
    print(f"{cl:<10} {m.sum():>5,}  {mc_['accuracy']:>7.4f} {mn_['accuracy']:>7.4f} {mc_['accuracy']-mn_['accuracy']:>+7.4f}"
          f"  {mc_['f1_macro']:>6.4f} {mn_['f1_macro']:>6.4f}  {mc_['qwk']:>7.4f} {mn_['qwk']:>7.4f}")
# Out:
# Client         N    Acc_C   Acc_N    Drop    F1_C   F1_N    QWK_C   QWK_N
# ------------------------------------------------------------------------------
# DDR          560   0.5089  0.3679 +0.1411  0.4316 0.2569   0.7168  0.3923
# EyePACS    1,288   0.4092  0.2446 +0.1646  0.4042 0.2099   0.5156  0.1385
# APTOS        279   0.4194  0.2330 +0.1864  0.4081 0.1975   0.6496  0.1770

# %% [markdown]
# ## 17. Confusion Matrices

# %%
SN=["NoDR","Mild","Mod.","Sev.","Prol."]
cm_c=confusion_matrix(y_test,yd_clean,labels=np.arange(NUM_CLASSES))
cm_n=confusion_matrix(y_test,yd_noisy,labels=np.arange(NUM_CLASSES))

fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,cm,title in [(ax[0],cm_c,"Clean"),(ax[1],cm_n,"Noisy")]:
    im=a.imshow(cm,cmap="Blues"); plt.colorbar(im,ax=a,fraction=.046)
    a.set_xticks(range(NUM_CLASSES)); a.set_yticks(range(NUM_CLASSES))
    a.set_xticklabels(SN,rotation=30,ha="right"); a.set_yticklabels(SN)
    th=cm.max()/2
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            a.text(j,i,str(cm[i,j]),ha="center",va="center",fontsize=9,color="white" if cm[i,j]>th else "black")
    a.set_xlabel("Predicted"); a.set_ylabel("True"); a.set_title(f"Noise-Aware FedAvg — {title}")
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/confusion_matrices.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 18. ROC Curves

# %%
yb=label_binarize(y_test,classes=np.arange(NUM_CLASSES))
COLS=plt.cm.tab10(np.linspace(0,1,NUM_CLASSES))
fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,yprob,title in [(ax[0],yp_clean,"Clean"),(ax[1],yp_noisy,"Noisy")]:
    for i in range(NUM_CLASSES):
        fpr,tpr,_=roc_curve(yb[:,i],yprob[:,i])
        a.plot(fpr,tpr,color=COLS[i],lw=1.8,label=f"{CLASS_NAMES[i]} (AUC={auc(fpr,tpr):.3f})")
    a.plot([0,1],[0,1],"k--",lw=1); a.set_xlabel("FPR"); a.set_ylabel("TPR")
    a.set_title(f"Noise-Aware FedAvg ROC — {title}"); a.legend(fontsize=9,loc="lower right"); a.grid(alpha=.3)
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/roc_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 19. Robustness Drop Visualization

# %%
MLABELS=["Accuracy","Precision","Recall","F1","AUC-ROC","QWK"]
cv=[mc[k] for k in MKEYS]; nv=[mn[k] for k in MKEYS]; dv=[rob[f"drop_{k}"] for k in MKEYS]
x=np.arange(len(MLABELS)); w=.35

fig,ax=plt.subplots(1,2,figsize=(13,5))
ax[0].bar(x-w/2,cv,w,label="Clean",color="#4CAF50",alpha=.85)
ax[0].bar(x+w/2,nv,w,label="Noisy",color="#E53935",alpha=.85)
for i,(a_,b_) in enumerate(zip(cv,nv)):
    ax[0].text(i-w/2,a_+.01,f"{a_:.3f}",ha="center",fontsize=8)
    ax[0].text(i+w/2,b_+.01,f"{b_:.3f}",ha="center",fontsize=8)
ax[0].set_xticks(x); ax[0].set_xticklabels(MLABELS); ax[0].set_ylim(0,1.1)
ax[0].set_title("Clean vs Noisy"); ax[0].legend(); ax[0].grid(axis="y",alpha=.3)

clrs=["#4CAF50" if d<=.05 else "#FFC107" if d<=.1 else "#F44336" for d in dv]
ax[1].bar(x,dv,color=clrs,alpha=.85,edgecolor="black",lw=.5)
for i,d in enumerate(dv): ax[1].text(i,d+.003,f"{d:+.3f}",ha="center",fontsize=9,fontweight="bold")
ax[1].set_xticks(x); ax[1].set_xticklabels(MLABELS)
ax[1].set_title("Robustness Drop (↓ = lebih robust)"); ax[1].axhline(0,color="k",lw=.8,ls="--"); ax[1].grid(axis="y",alpha=.3)
plt.suptitle(f"Noise-Aware FedAvg — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/robustness_drop.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 20. Save Results + Summary

# %%
res={
    "experiment":EXPERIMENT_NAME,"model":MODEL_NAME,"paradigm":"Noise-Aware FedAvg",
    "use_noise_aug":USE_NOISE_AUG,"noisy_clients":NOISY_CLIENTS,
    "client_sizes":dict(zip(CLIENT_NAMES,[int(s) for s in csz])),
    "n_test":int(len(y_test)),
    "metrics_clean":mc,"metrics_noisy":mn,"robustness_drop":rob,
    "per_client":pcc,
    "confusion_matrix_clean":cm_c.tolist(),"confusion_matrix_noisy":cm_n.tolist(),
    "config":dict(seed=SEED,noisy_test_seed=NOISY_TEST_SEED,batch=BATCH_SIZE,lr=LR,
                  fl_rounds=FL_ROUNDS,local_epochs=LOCAL_EPOCHS,
                  stage1_rounds=STAGE1_ROUNDS,unfreeze_n=UNFREEZE_N,
                  noise_prob=NOISE_PROB,blur_prob=BLUR_PROB,bright_prob=BRIGHT_PROB)
}
with open(f"{LOG_DIR}/results.json","w") as f: json.dump(res,f,indent=2)

row={"experiment":EXPERIMENT_NAME,"paradigm":"Noise-Aware FedAvg","model":MODEL_NAME}
row.update({f"clean_{k}":mc[k] for k in MKEYS})
row.update({f"noisy_{k}":mn[k] for k in MKEYS})
row.update(rob)
pd.DataFrame([row]).to_csv(f"{LOG_DIR}/summary_row.csv",index=False)
print(f"Saved to: {RES}")

print("\n"+"="*65)
print(f"  EXP3 NOISE-AWARE FEDAVG — DONE")
print("="*65)
print(f"  Noisy clients: {NOISY_CLIENTS}")
print(f"  CLEAN  | Acc:{mc['accuracy']:.4f}  F1:{mc['f1_macro']:.4f}  AUC:{mc['auc_roc']:.4f}  QWK:{mc['qwk']:.4f}")
print(f"  NOISY  | Acc:{mn['accuracy']:.4f}  F1:{mn['f1_macro']:.4f}  AUC:{mn['auc_roc']:.4f}  QWK:{mn['qwk']:.4f}")
print(f"  DROP   | Acc:{rob['drop_accuracy']:+.4f}  F1:{rob['drop_f1_macro']:+.4f}  AUC:{rob['drop_auc_roc']:+.4f}  QWK:{rob['drop_qwk']:+.4f}")
print("="*65)
print("\n  >>> Bandingin DROP ini sama Exp1 & Exp2 — harusnya PALING KECIL <<<")
# Out:
# Saved to: /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/MobileNetV2/exp3_noise_aware_fl
#
# =================================================================
#   EXP3 NOISE-AWARE FEDAVG — DONE
# =================================================================
#   Noisy clients: ['DDR', 'EyePACS', 'APTOS']
#   CLEAN  | Acc:0.4368  F1:0.4218  AUC:0.7628  QWK:0.6069
#   NOISY  | Acc:0.2755  F1:0.2260  AUC:0.6329  QWK:0.2169
#   DROP   | Acc:+0.1613  F1:+0.1958  AUC:+0.1299  QWK:+0.3899
# =================================================================
#
#   >>> Bandingin DROP ini sama Exp1 & Exp2 — harusnya PALING KECIL <<<

# %%
# ── AUTO SHUTDOWN RUNTIME (Colab) ────────────────────────────────
import time

print("Training selesai. Runtime akan shutdown dalam 60 detik...")
print("Tekan Ctrl+C untuk batalkan.")

try:
    for i in range(60, 0, -5):
        print(f"  Shutdown dalam {i} detik...")
        time.sleep(5)
    from google.colab import runtime
    runtime.unassign()
except KeyboardInterrupt:
    print("Shutdown dibatalkan.")
except Exception as e:
    print(f"Colab runtime unassign gagal: {e}")
    # Fallback
    import subprocess
    subprocess.run(["kill", "-9", "-1"], check=False)
# Out:
# Training selesai. Runtime akan shutdown dalam 60 detik...
# Tekan Ctrl+C untuk batalkan.
#   Shutdown dalam 60 detik...
#   Shutdown dalam 55 detik...
#   Shutdown dalam 50 detik...
#   Shutdown dalam 45 detik...
#   Shutdown dalam 40 detik...
#   Shutdown dalam 35 detik...
#   Shutdown dalam 30 detik...
#   Shutdown dalam 25 detik...
#   Shutdown dalam 20 detik...
#   Shutdown dalam 15 detik...
#   Shutdown dalam 10 detik...
#   Shutdown dalam 5 detik...
