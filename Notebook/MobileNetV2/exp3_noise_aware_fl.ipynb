# %% [markdown]
# <a href="https://colab.research.google.com/github/Akira006/noise-aware-federated-learning-dr/blob/main/Notebook/MobileNetV2/exp3_noise_aware_fl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 3 — Noise-Aware Federated Learning (Proposed Method)
# **Project:** Noise-Aware Federated Learning for Robust Diabetic Retinopathy Classification
# **Model:** MobileNetV2 | **Paradigm:** Noise-Aware FedAvg
#
# | Config | Value |
# |--------|-------|
# | Clients | DDR, EyePACS, APTOS |
# | Communication Rounds | 20 (rounds 1-10 frozen, 11-20 unfrozen) |
# | Local Epochs / Round | 5 |
# | Noise aug (training) | ✅ Stochastic (50% prob tiap jenis degradasi, semua client) |
# | Aggregation | Dataset-size-weighted FedAvg |
# | Test | Clean + Noisy (seed=123, identik di 3 notebook) |
#
# **Key difference dari Exp2:** Setiap sample training di-augment secara stochastic on-the-fly.
# Tiap pass beda — mirip kondisi nyata di fasilitas low-resource.
#
# > ⚠️ **JANGAN ubah `SEED` dan `NOISY_TEST_SEED`** — harus konsisten di 3 notebook.

# %% [markdown]
# ## 1. GPU Check

# %%
# !nvidia-smi
# Out:
# Fri May 29 13:09:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   38C    P0             53W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Cell 1 — GPU Setup (taruh sebelum semua import)
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"  # lebih stable di G4/L4
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"✓ GPU: {gpus[0].name}")
    print(f"✓ TF version: {tf.__version__}")
else:
    print("No GPU detected")
# Out:
# ✓ GPU: /physical_device:GPU:0
# ✓ TF version: 2.20.0

# %% [markdown]
# ## 2. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# GPU Memory Growth — prevent CUDA_ERROR_INVALID_HANDLE
import os
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"] = "true"

import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
    print(f"GPU memory growth enabled: {len(gpus)} GPU(s)")
# Out:
# GPU memory growth enabled: 1 GPU(s)

# %% [markdown]
# ## 3. Imports

# %%
import os, json, random, time, gc, warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    confusion_matrix, accuracy_score,
    precision_recall_fscore_support,
    roc_auc_score, roc_curve, auc, cohen_kappa_score
)
from sklearn.preprocessing import label_binarize

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.applications import MobileNetV2

print("TF:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 4. Configuration

# %%
# ── REPRODUCIBILITY (sama di 3 notebook) ─────────────────────────
SEED             = 42
NOISY_TEST_SEED  = 123
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# ── MODEL & EXPERIMENT ────────────────────────────────────────────
MODEL_NAME       = "MobileNetV2"
EXPERIMENT_NAME  = "exp3_noise_aware_fl"

# ── TRAINING ──────────────────────────────────────────────────────
IMG_SIZE         = (224, 224)
NUM_CLASSES      = 5
BATCH_SIZE       = 32
LR               = 1e-4
UNFREEZE_N       = 20
DROPOUT          = 0.4
L2               = 1e-4
# ── FL CONFIG ─────────────────────────────────────────────────────
FL_ROUNDS        = 40
LOCAL_EPOCHS     = 5
STAGE1_ROUNDS    = 17
STAGE2_ROUNDS    = 23
CLIENT_NAMES     = ["DDR","EyePACS","APTOS"]
USE_NOISE_AUG    = True
NOISY_CLIENTS    = ["DDR","EyePACS","APTOS"]   # semua client — sesuai Fig 2c paper

# ── NOISE PARAMS (sesuai Draft Paper Section III.B) ───────────────
NS_MIN, NS_MAX   = 0.01, 0.05     # Gaussian noise sigma
BL_MIN, BL_MAX   = 1.0,  3.0     # Gaussian blur sigma
BR_DELTA         = 0.2            # Brightness delta
CT_LOW, CT_HIGH  = 0.7,  1.3     # Contrast range
NOISE_PROB       = 0.5            # Probability per degradation type
BLUR_PROB        = 0.5
BRIGHT_PROB      = 0.5

CLASS_NAMES  = ["No DR","Mild","Moderate","Severe","Proliferative"]

# ── PATHS ─────────────────────────────────────────────────────────
PROJECT  = "/content/drive/MyDrive/Binus/Semester_4/Research_Methodology"
DS_BASE  = "/content/drive/MyDrive/S-Class/Orion/OrionFL"
BALANCED_DIR = f"{DS_BASE}/balanced"

APTOS_NPZ  = f"{DS_BASE}/balanced/aptos_balanced.npz"
DDR_NPZ    = f"{DS_BASE}/balanced/ddr_balanced.npz"
EYE_NPZ    = f"{DS_BASE}/balanced/eyepacs_balanced.npz"

RES      = f"{PROJECT}/Result/{MODEL_NAME}/{EXPERIMENT_NAME}"
MDL_DIR  = f"{RES}/models"
LOG_DIR  = f"{RES}/logs"
FIG_DIR  = f"{RES}/figures"
for d in [MDL_DIR, LOG_DIR, FIG_DIR]: os.makedirs(d, exist_ok=True)

print(f"Model        : {MODEL_NAME}  |  Use noise aug: {USE_NOISE_AUG}")
print(f"Noisy clients: {NOISY_CLIENTS}")
print(f"FL rounds    : {FL_ROUNDS} ({STAGE1_ROUNDS} frozen + {STAGE2_ROUNDS} unfrozen)")
print(f"Results      : {RES}")
# Out:
# Model        : MobileNetV2  |  Use noise aug: True
# Noisy clients: ['DDR', 'EyePACS', 'APTOS']
# FL rounds    : 40 (17 frozen + 23 unfrozen)
# Results      : /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/MobileNetV2/exp3_noise_aware_fl

# %% [markdown]
# ## 5. Load & Split Per Client (70:15:15)

# %%
def to01(X):
    X = X.astype(np.float32)
    return X / 255.0 if X.max() > 1.0 else X

def split_dataset(X, y, seed=SEED):
    X_tr,X_tmp,y_tr,y_tmp = train_test_split(X,y,test_size=.30,random_state=seed,stratify=y)
    X_v,X_te,y_v,y_te     = train_test_split(X_tmp,y_tmp,test_size=.50,random_state=seed,stratify=y_tmp)
    return X_tr,X_v,X_te,y_tr,y_v,y_te

print("Loading DDR...")
d = np.load(DDR_NPZ, allow_pickle=True)
X_ddr, y_ddr = to01(d["images"]), d["labels"].astype(np.int64)

print("Loading EyePACS...")
d = np.load(EYE_NPZ, allow_pickle=True)
X_eye = to01(d["images"])
y_eye = d["labels"].astype(np.int64)

print("Loading APTOS...")
d = np.load(APTOS_NPZ, allow_pickle=True)
X_apt, y_apt = to01(d["images"]), d["labels"].astype(np.int64)

Xtr_d,Xv_d,Xte_d,ytr_d,yv_d,yte_d = split_dataset(X_ddr, y_ddr)
Xtr_e,Xv_e,Xte_e,ytr_e,yv_e,yte_e = split_dataset(X_eye, y_eye)
Xtr_a,Xv_a,Xte_a,ytr_a,yv_a,yte_a = split_dataset(X_apt, y_apt)
del X_ddr, X_eye, X_apt; gc.collect()

Xtr = [Xtr_d, Xtr_e, Xtr_a]
ytr = [ytr_d, ytr_e, ytr_a]
csz = [len(ytr_d), len(ytr_e), len(ytr_a)]

X_val   = np.concatenate([Xv_d,  Xv_e,  Xv_a])
y_val   = np.concatenate([yv_d,  yv_e,  yv_a])
X_test  = np.concatenate([Xte_d, Xte_e, Xte_a])
y_test  = np.concatenate([yte_d, yte_e, yte_a])
src_test= np.array(["DDR"]*len(yte_d)+["EyePACS"]*len(yte_e)+["APTOS"]*len(yte_a))

print(f"\nClient sizes: {dict(zip(CLIENT_NAMES, csz))}")
print(f"Val:{len(y_val):,}  |  Test:{len(y_test):,}")
# Out:
# Loading DDR...
# Loading EyePACS...
# Loading APTOS...
#
# Client sizes: {'DDR': 7513, 'EyePACS': 7366, 'APTOS': 1999}
# Val:3,617  |  Test:3,618

# %% [markdown]
# ## 6. Per-Client Class Weights

# %%
def get_cw(y):
    cls = np.unique(y)
    cw  = compute_class_weight("balanced", classes=cls, y=y)
    d   = {int(c):float(w) for c,w in zip(cls,cw)}
    for c in range(NUM_CLASSES): d.setdefault(c, 1.0)
    return d

cws = [get_cw(y) for y in ytr]
for name,cw in zip(CLIENT_NAMES,cws): print(f"{name}: {cw}")
# Out:
# DDR: {0: 0.47945118059987235, 1: 3.4072562358276643, 2: 0.47945118059987235, 3: 9.106666666666667, 4: 2.351486697965571}
# EyePACS: {0: 0.5261428571428571, 1: 0.8615204678362574, 2: 0.8418285714285715, 3: 2.4111292962356794, 4: 2.9761616161616162}
# APTOS: {0: 0.5719599427753934, 1: 1.5436293436293436, 2: 0.5719599427753934, 3: 2.9614814814814814, 4: 1.931400966183575}

# %% [markdown]
# ## 7. Noise Pipeline
#
# Dua mode:
# - **Stochastic** (training): probabilistic per degradation, fresh rng tiap sample
# - **Deterministic** (test set): always-apply semua jenis, seeded → reproducible

# %%
def gauss_noise(img,sigma): return np.clip(img+np.random.normal(0,sigma,img.shape).astype(np.float32),0,1)
def gauss_blur(img, sigma):
    # Fix: pastikan output shape sama persis dengan input
    out = np.empty_like(img)
    for c in range(img.shape[2]):
        out[:, :, c] = gaussian_filter(img[:, :, c], sigma=sigma)
    return np.clip(out.astype(np.float32), 0, 1)
def bright_contrast(img,bd,cf): m=img.mean(); return np.clip(((img-m)*cf+m+bd).astype(np.float32),0,1)

def stochastic_degrade(img):
    """Probabilistic aug — tiap degradation 50% chance. Dipakai saat TRAINING."""
    rng = np.random.default_rng()
    img = img.copy()
    if rng.random() < NOISE_PROB:  img = gauss_noise(img,     rng.uniform(NS_MIN,NS_MAX))
    if rng.random() < BLUR_PROB:   img = gauss_blur(img,      rng.uniform(BL_MIN,BL_MAX))
    if rng.random() < BRIGHT_PROB: img = bright_contrast(img, rng.uniform(-BR_DELTA,BR_DELTA), rng.uniform(CT_LOW,CT_HIGH))
    return img

def deterministic_degrade(img, rng):
    """Always apply all 3 degradations (seeded). Dipakai untuk fixed noisy test set."""
    img = img.copy()
    img = gauss_noise(img,     rng.uniform(NS_MIN,NS_MAX))
    img = gauss_blur(img,      rng.uniform(BL_MIN,BL_MAX))
    img = bright_contrast(img, rng.uniform(-BR_DELTA,BR_DELTA), rng.uniform(CT_LOW,CT_HIGH))
    return img

def make_noisy_set(X, seed=NOISY_TEST_SEED):
    print(f"  Generating noisy test set (n={len(X)}, seed={seed})...")
    rng = np.random.default_rng(seed); out = np.empty_like(X)
    for i in range(len(X)): out[i] = deterministic_degrade(X[i], rng)
    print(f"  Done. range=[{out.min():.3f},{out.max():.3f}]")
    return out

X_test_noisy = make_noisy_set(X_test)
# Out:
#   Generating noisy test set (n=3618, seed=123)...
#   Done. range=[0.000,1.000]

# %% [markdown]
# ## 8. Visualize Stochastic Augmentation

# %%
sample = Xtr[0][0]
fig, axes = plt.subplots(1,5,figsize=(16,4))
axes[0].imshow(sample); axes[0].set_title("Original"); axes[0].axis("off")
for i in range(4):
    aug = stochastic_degrade(sample)
    axes[i+1].imshow(aug); axes[i+1].set_title(f"Aug #{i+1}"); axes[i+1].axis("off")
plt.suptitle("Stochastic Aug — 4 different realizations of same image", fontweight="bold")
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/stochastic_aug_preview.png", dpi=150, bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 9. Model Builder + TF Dataset Helpers

# %%
AUT = tf.data.AUTOTUNE

def make_ds(X, y, shuffle=False, seed=None):
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).prefetch(AUT)

def make_noisy_train_ds(X, y, shuffle=True, seed=None):
    """Training dataset with on-the-fly stochastic augmentation."""
    def tf_aug(x, label):
        def np_aug(img_np):
            return stochastic_degrade(img_np.numpy()).astype(np.float32)
        x_aug = tf.py_function(np_aug, [x], tf.float32)
        x_aug.set_shape(x.shape)   # prevent shape=None crash
        return x_aug, label
    ds = tf.data.Dataset.from_tensor_slices((X,y))
    if shuffle: ds = ds.shuffle(len(X), seed=seed)
    return ds.batch(BATCH_SIZE).map(tf_aug, num_parallel_calls=AUT).prefetch(AUT)

def build_model(stage=1):
    base = MobileNetV2(include_top=False, weights="imagenet", input_shape=(224,224,3))
    base.trainable = False
    if stage == 2:
        base.trainable = True
        for l in base.layers[:-UNFREEZE_N]: l.trainable = False
        for l in base.layers[-UNFREEZE_N:]: l.trainable = True
        for l in base.layers:
            if isinstance(l, layers.BatchNormalization): l.trainable = False
    inp = keras.Input((224,224,3))
    x   = base(inp, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dropout(DROPOUT)(x)
    out = layers.Dense(NUM_CLASSES, activation="softmax",
                       kernel_regularizer=regularizers.l2(L2))(x)
    return keras.Model(inp, out)

def fedavg(weights_list, sizes):
    total = sum(sizes)
    return [np.sum([weights_list[i][li]*(sizes[i]/total) for i in range(len(sizes))],axis=0)
            for li in range(len(weights_list[0]))]

# Eval datasets (always clean)
val_ds     = make_ds(X_val, y_val)
test_clean = make_ds(X_test, y_test)
test_noisy = make_ds(X_test_noisy, y_test)
print("Model + dataset helpers ready.")
# Out:
# Model + dataset helpers ready.

# %% [markdown]
# ## 10. Local Training Function
#
# Clients di `NOISY_CLIENTS` → training pakai **stochastic noisy dataset**.
# Clients lain → clean dataset.
# Eksperimen ini: semua 3 client masuk `NOISY_CLIENTS` (sesuai Fig 2c paper).

# %%
def local_train(global_w, X, y, cw, client_name, stage, seed):
    m = build_model(stage)
    m.set_weights(global_w)
    m.compile(optimizer=keras.optimizers.Adam(LR),
               loss=keras.losses.SparseCategoricalCrossentropy(),
               metrics=["accuracy"])

    # Conditional noise application
    if client_name in NOISY_CLIENTS:
        ds  = make_noisy_train_ds(X, y, shuffle=True, seed=seed)
        tag = "[+NOISE]"
    else:
        ds  = make_ds(X, y, shuffle=True, seed=seed)
        tag = "[clean]"

    h   = m.fit(ds, epochs=LOCAL_EPOCHS, class_weight=cw, verbose=0)
    w, loss, acc = m.get_weights(), h.history["loss"][-1], h.history["accuracy"][-1]
    del m, ds; tf.keras.backend.clear_session(); gc.collect()
    return w, float(loss), float(acc), tag

print("local_train (noise-aware) ready.")
# Out:
# local_train (noise-aware) ready.

# %% [markdown]
# ## 11. FL Training Loop — Noise-Aware FedAvg

# %%
gm = build_model(stage=1)
gm.compile(optimizer=keras.optimizers.Adam(LR),
            loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
gw = gm.get_weights(); del gm; tf.keras.backend.clear_session(); gc.collect()

fl_logs = []
print("="*65)
print(f"  Noise-Aware FedAvg | {FL_ROUNDS} rounds × {LOCAL_EPOCHS} local epochs")
print(f"  Noisy clients: {NOISY_CLIENTS}")
print(f"  Stage 1: rounds 1-{STAGE1_ROUNDS} | Stage 2: rounds {STAGE1_ROUNDS+1}-{FL_ROUNDS}")
print("="*65)

for rnd in tqdm(range(1, FL_ROUNDS+1), desc="FL Rounds"):
    t0    = time.time()
    stage = 1 if rnd <= STAGE1_ROUNDS else 2
    print(f"\n[Round {rnd:02d}/{FL_ROUNDS}] Stage {stage}")

    client_ws, client_logs = [], []
    for ci,(cname,cX,cy,cw) in enumerate(zip(CLIENT_NAMES,Xtr,ytr,cws)):
        cw_,loss,acc,tag = local_train(gw,cX,cy,cw,cname,stage,seed=SEED+rnd)
        client_ws.append(cw_)
        client_logs.append({"client":cname,"stage":stage,"noise":cname in NOISY_CLIENTS,
                             "loss":loss,"accuracy":acc,"n":int(csz[ci])})
        print(f"  ✓ {cname:<8} {tag} loss:{loss:.4f}  acc:{acc:.4f}  n:{csz[ci]:,}")

    gw = fedavg(client_ws, csz)

    gm = build_model(stage)
    gm.set_weights(gw)
    gm.compile(optimizer=keras.optimizers.Adam(LR),
                loss=keras.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])
    vl, va = gm.evaluate(val_ds, verbose=0)
    elapsed = time.time()-t0
    print(f"  ▶ Val loss:{vl:.4f}  acc:{va:.4f}  ({elapsed:.1f}s)")

    fl_logs.append({"round":rnd,"stage":stage,"val_loss":float(vl),"val_accuracy":float(va),
                    "time_sec":round(elapsed,2),"clients":client_logs})

    gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_round{rnd:02d}.keras")
    del client_ws; gc.collect()

print("\n"+"="*65+"\n  FL TRAINING COMPLETE\n"+"="*65)
gm.save(f"{MDL_DIR}/{EXPERIMENT_NAME}_final.keras")

pd.DataFrame([{"round":r["round"],"stage":r["stage"],"val_acc":r["val_accuracy"],
               "val_loss":r["val_loss"],"time_sec":r["time_sec"]} for r in fl_logs]
).to_csv(f"{LOG_DIR}/fl_round_summary.csv",index=False)
print(f"Round logs saved.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# =================================================================
#   Noise-Aware FedAvg | 40 rounds × 5 local epochs
#   Noisy clients: ['DDR', 'EyePACS', 'APTOS']
#   Stage 1: rounds 1-17 | Stage 2: rounds 18-40
# =================================================================
# FL Rounds:   0%|          | 0/40 [00:00<?, ?it/s]
# [Round 01/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.6876  acc:0.2705  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.7310  acc:0.2300  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.7239  acc:0.2896  n:1,999
#   ▶ Val loss:1.4688  acc:0.3359  (340.5s)
#
# [Round 02/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5751  acc:0.2975  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.6659  acc:0.2486  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.6367  acc:0.3347  n:1,999
#   ▶ Val loss:1.3939  acc:0.3738  (282.6s)
#
# [Round 03/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5375  acc:0.3008  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.6275  acc:0.2430  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.5243  acc:0.3757  n:1,999
#   ▶ Val loss:1.3420  acc:0.4164  (280.4s)
#
# [Round 04/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4774  acc:0.3160  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5969  acc:0.2487  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4900  acc:0.3902  n:1,999
#   ▶ Val loss:1.3380  acc:0.4172  (283.6s)
#
# [Round 05/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.5237  acc:0.3041  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5610  acc:0.2596  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.5044  acc:0.3567  n:1,999
#   ▶ Val loss:1.3414  acc:0.3992  (278.6s)
#
# [Round 06/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4686  acc:0.3031  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5372  acc:0.2615  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3928  acc:0.4387  n:1,999
#   ▶ Val loss:1.3188  acc:0.4161  (279.8s)
#
# [Round 07/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.3980  acc:0.3204  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5601  acc:0.2575  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3805  acc:0.4232  n:1,999
#   ▶ Val loss:1.3172  acc:0.4224  (276.7s)
#
# [Round 08/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4391  acc:0.3213  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5565  acc:0.2488  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4300  acc:0.4047  n:1,999
#   ▶ Val loss:1.2927  acc:0.4412  (281.2s)
#
# [Round 09/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4391  acc:0.3089  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5193  acc:0.2719  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3675  acc:0.4237  n:1,999
#   ▶ Val loss:1.3123  acc:0.4244  (281.6s)
#
# [Round 10/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4104  acc:0.3264  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5351  acc:0.2624  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4544  acc:0.3732  n:1,999
#   ▶ Val loss:1.3019  acc:0.4302  (281.8s)
#
# [Round 11/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4106  acc:0.3194  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5042  acc:0.2790  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4123  acc:0.4052  n:1,999
#   ▶ Val loss:1.2910  acc:0.4236  (275.4s)
#
# [Round 12/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4133  acc:0.3092  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5019  acc:0.2723  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4076  acc:0.4097  n:1,999
#   ▶ Val loss:1.2965  acc:0.4260  (270.6s)
#
# [Round 13/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.3996  acc:0.3393  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5066  acc:0.2772  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3885  acc:0.4127  n:1,999
#   ▶ Val loss:1.2973  acc:0.4213  (275.8s)
#
# [Round 14/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4142  acc:0.3173  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5090  acc:0.2674  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4086  acc:0.4057  n:1,999
#   ▶ Val loss:1.2964  acc:0.4258  (278.7s)
#
# [Round 15/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.3956  acc:0.3462  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4963  acc:0.2680  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4018  acc:0.4057  n:1,999
#   ▶ Val loss:1.3167  acc:0.3992  (283.1s)
#
# [Round 16/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.4093  acc:0.3168  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.5017  acc:0.2695  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.4074  acc:0.4117  n:1,999
#   ▶ Val loss:1.2985  acc:0.4224  (277.4s)
#
# [Round 17/40] Stage 1
#   ✓ DDR      [+NOISE] loss:1.3831  acc:0.3501  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4953  acc:0.2850  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3976  acc:0.4192  n:1,999
#   ▶ Val loss:1.2947  acc:0.4294  (291.5s)
#
# [Round 18/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.4048  acc:0.3021  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4940  acc:0.2570  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.3444  acc:0.4212  n:1,999
#   ▶ Val loss:1.4780  acc:0.2676  (296.9s)
#
# [Round 19/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3724  acc:0.3297  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4625  acc:0.2904  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2842  acc:0.4812  n:1,999
#   ▶ Val loss:1.3998  acc:0.3727  (291.7s)
#
# [Round 20/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3114  acc:0.3234  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4475  acc:0.2755  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2917  acc:0.4652  n:1,999
#   ▶ Val loss:1.3676  acc:0.3152  (292.6s)
#
# [Round 21/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3031  acc:0.3582  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4379  acc:0.2869  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2685  acc:0.4752  n:1,999
#   ▶ Val loss:1.3240  acc:0.3459  (290.2s)
#
# [Round 22/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.3110  acc:0.3431  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4335  acc:0.2788  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2770  acc:0.4597  n:1,999
#   ▶ Val loss:1.3247  acc:0.3752  (290.4s)
#
# [Round 23/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2380  acc:0.4058  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3978  acc:0.3070  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2184  acc:0.4822  n:1,999
#   ▶ Val loss:1.3178  acc:0.3719  (290.5s)
#
# [Round 24/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2219  acc:0.3626  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.4116  acc:0.2943  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2592  acc:0.4492  n:1,999
#   ▶ Val loss:1.3589  acc:0.3713  (299.5s)
#
# [Round 25/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2187  acc:0.3932  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3912  acc:0.2951  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1657  acc:0.4967  n:1,999
#   ▶ Val loss:1.2711  acc:0.3976  (292.4s)
#
# [Round 26/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1854  acc:0.3929  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3547  acc:0.3116  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2862  acc:0.4407  n:1,999
#   ▶ Val loss:1.2640  acc:0.4130  (298.1s)
#
# [Round 27/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1791  acc:0.3994  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3438  acc:0.3196  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1672  acc:0.5098  n:1,999
#   ▶ Val loss:1.2691  acc:0.4357  (293.5s)
#
# [Round 28/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.2321  acc:0.3679  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3225  acc:0.3336  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2418  acc:0.4732  n:1,999
#   ▶ Val loss:1.2724  acc:0.4241  (299.7s)
#
# [Round 29/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1976  acc:0.3907  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3066  acc:0.3406  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1814  acc:0.5023  n:1,999
#   ▶ Val loss:1.3047  acc:0.4158  (296.9s)
#
# [Round 30/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1231  acc:0.4199  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3177  acc:0.3365  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1160  acc:0.5223  n:1,999
#   ▶ Val loss:1.3870  acc:0.4487  (294.3s)
#
# [Round 31/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1737  acc:0.3978  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.3094  acc:0.3380  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1417  acc:0.5168  n:1,999
#   ▶ Val loss:1.3166  acc:0.4164  (295.0s)
#
# [Round 32/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1347  acc:0.4154  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2543  acc:0.3551  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1525  acc:0.5098  n:1,999
#   ▶ Val loss:1.3725  acc:0.4042  (296.7s)
#
# [Round 33/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1742  acc:0.4084  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2572  acc:0.3613  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2222  acc:0.4847  n:1,999
#   ▶ Val loss:1.2528  acc:0.4352  (299.6s)
#
# [Round 34/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1735  acc:0.3877  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2674  acc:0.3542  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2169  acc:0.4822  n:1,999
#   ▶ Val loss:1.3247  acc:0.4335  (299.9s)
#
# [Round 35/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1480  acc:0.4199  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2252  acc:0.3697  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2146  acc:0.5033  n:1,999
#   ▶ Val loss:1.3639  acc:0.4382  (304.5s)
#
# [Round 36/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1308  acc:0.4303  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2564  acc:0.3820  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.2619  acc:0.4642  n:1,999
#   ▶ Val loss:1.3559  acc:0.4202  (299.2s)
#
# [Round 37/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1542  acc:0.4081  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2003  acc:0.3858  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1234  acc:0.5298  n:1,999
#   ▶ Val loss:1.3867  acc:0.4354  (302.4s)
#
# [Round 38/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1038  acc:0.4247  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2056  acc:0.3774  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.1320  acc:0.5363  n:1,999
#   ▶ Val loss:1.5554  acc:0.4130  (300.7s)
#
# [Round 39/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.0072  acc:0.4669  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.2132  acc:0.3922  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.0913  acc:0.5303  n:1,999
#   ▶ Val loss:1.4575  acc:0.4553  (307.5s)
#
# [Round 40/40] Stage 2
#   ✓ DDR      [+NOISE] loss:1.1411  acc:0.4255  n:7,513
#   ✓ EyePACS  [+NOISE] loss:1.1732  acc:0.4199  n:7,366
#   ✓ APTOS    [+NOISE] loss:1.0927  acc:0.5348  n:1,999
#   ▶ Val loss:1.5302  acc:0.3777  (299.7s)
#
# =================================================================
#   FL TRAINING COMPLETE
# =================================================================
# Round logs saved.

# %% [markdown]
# ## 12. FL Training Curves

# %%
rounds   = [r["round"] for r in fl_logs]
val_acc  = [r["val_accuracy"] for r in fl_logs]
val_loss = [r["val_loss"] for r in fl_logs]
sb       = next((r for r,s in zip(rounds,[r["stage"] for r in fl_logs]) if s==2), None)

fig,ax = plt.subplots(1,2,figsize=(13,5))
for a,data,title in [(ax[0],val_acc,"Val Accuracy"),(ax[1],val_loss,"Val Loss")]:
    a.plot(rounds,data,marker="o",color="#4CAF50",lw=2)
    if sb: a.axvline(sb-.5,color="gray",ls=":",lw=1.5,label="S1→S2"); a.legend()
    a.set_xlabel("Round"); a.set_ylabel(title); a.set_title(f"Noise-Aware FedAvg — {title}")
    a.grid(alpha=.3); a.set_xticks(rounds)
plt.suptitle(f"Noise-Aware FedAvg — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/fl_training_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 13. Predict Clean + Noisy

# %%
print("Predicting clean...")
yp_clean = gm.predict(test_clean, verbose=1)
yd_clean = np.argmax(yp_clean,1)

print("Predicting noisy...")
yp_noisy = gm.predict(test_noisy, verbose=1)
yd_noisy = np.argmax(yp_noisy,1)
# Out:
# Predicting clean...
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 16s 101ms/step
# Predicting noisy...
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step

# %% [markdown]
# ## 14. Metrics + Robustness Drop

# %%
def metrics(yt,yp,yprob):
    a = accuracy_score(yt,yp)
    p,r,f,_ = precision_recall_fscore_support(yt,yp,average="macro",zero_division=0)
    yb = label_binarize(yt,classes=np.arange(NUM_CLASSES))
    try: au = roc_auc_score(yb,yprob,multi_class="ovr",average="macro")
    except: au = float("nan")
    q = cohen_kappa_score(yt,yp,weights="quadratic")
    return dict(accuracy=float(a),precision_macro=float(p),recall_macro=float(r),
                f1_macro=float(f),auc_roc=float(au),qwk=float(q))

MKEYS = ["accuracy","precision_macro","recall_macro","f1_macro","auc_roc","qwk"]
mc = metrics(y_test,yd_clean,yp_clean)
mn = metrics(y_test,yd_noisy,yp_noisy)

print(f"{'Metric':<18} {'Clean':>8} {'Noisy':>8} {'Drop':>8}")
print("-"*44)
rob = {}
for k in MKEYS:
    d=mc[k]-mn[k]; rob[f"drop_{k}"]=float(d)
    print(f"{k:<18} {mc[k]:>8.4f} {mn[k]:>8.4f} {d:>+8.4f}")
# Out:
# Metric                Clean    Noisy     Drop
# --------------------------------------------
# accuracy             0.3850   0.1258  +0.2593
# precision_macro      0.4000   0.2893  +0.1107
# recall_macro         0.4565   0.2411  +0.2154
# f1_macro             0.3784   0.1046  +0.2738
# auc_roc              0.7496   0.5723  +0.1773
# qwk                  0.5664   0.0697  +0.4967

# %% [markdown]
# ## 15. Per-Class Metrics

# %%
def per_class(yt,yp):
    p,r,f,s = precision_recall_fscore_support(yt,yp,labels=np.arange(NUM_CLASSES),zero_division=0)
    return pd.DataFrame({"class":np.arange(NUM_CLASSES),"name":CLASS_NAMES,
                          "precision":p,"recall":r,"f1":f,"support":s})
pc_c=per_class(y_test,yd_clean); pc_n=per_class(y_test,yd_noisy)
print("CLEAN:"); print(pc_c.to_string(index=False))
print("\nNOISY:"); print(pc_n.to_string(index=False))
pc_c.to_csv(f"{LOG_DIR}/per_class_clean.csv",index=False)
pc_n.to_csv(f"{LOG_DIR}/per_class_noisy.csv",index=False)
# Out:
# CLEAN:
#  class          name  precision   recall       f1  support
#      0         No DR   0.743692 0.393812 0.514943     1422
#      1          Mild   0.222323 0.474806 0.302843      516
#      2      Moderate   0.447368 0.255639 0.325359     1197
#      3        Severe   0.161194 0.553846 0.249711      195
#      4 Proliferative   0.425428 0.604167 0.499283      288
#
# NOISY:
#  class          name  precision   recall       f1  support
#      0         No DR   0.870968 0.056962 0.106931     1422
#      1          Mild   0.177778 0.015504 0.028520      516
#      2      Moderate   0.237430 0.071011 0.109325     1197
#      3        Severe   0.048104 0.266667 0.081505      195
#      4 Proliferative   0.112200 0.795139 0.196651      288

# %% [markdown]
# ## 16. Per-Client Breakdown

# %%
print(f"{'Client':<10} {'N':>5}  {'Acc_C':>7} {'Acc_N':>7} {'Drop':>7}  {'F1_C':>6} {'F1_N':>6}  {'QWK_C':>7} {'QWK_N':>7}")
print("-"*78)
pcc = {}
for cl in CLIENT_NAMES:
    m = src_test==cl
    if not m.any(): continue
    mc_=metrics(y_test[m],yd_clean[m],yp_clean[m])
    mn_=metrics(y_test[m],yd_noisy[m],yp_noisy[m])
    pcc[cl]={"n":int(m.sum()),"clean":mc_,"noisy":mn_}
    print(f"{cl:<10} {m.sum():>5,}  {mc_['accuracy']:>7.4f} {mn_['accuracy']:>7.4f} {mc_['accuracy']-mn_['accuracy']:>+7.4f}"
          f"  {mc_['f1_macro']:>6.4f} {mn_['f1_macro']:>6.4f}  {mc_['qwk']:>7.4f} {mn_['qwk']:>7.4f}")
# Out:
# Client         N    Acc_C   Acc_N    Drop    F1_C   F1_N    QWK_C   QWK_N
# ------------------------------------------------------------------------------
# DDR        1,610   0.4379  0.1503 +0.2876  0.3924 0.1236   0.6642  0.1101
# EyePACS    1,579   0.3616  0.1045 +0.2571  0.3741 0.0927   0.4492  0.0308
# APTOS        429   0.2727  0.1119 +0.1608  0.2605 0.0799   0.5586  0.0844

# %% [markdown]
# ## 17. Confusion Matrices

# %%
SN=["NoDR","Mild","Mod.","Sev.","Prol."]
cm_c=confusion_matrix(y_test,yd_clean,labels=np.arange(NUM_CLASSES))
cm_n=confusion_matrix(y_test,yd_noisy,labels=np.arange(NUM_CLASSES))

fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,cm,title in [(ax[0],cm_c,"Clean"),(ax[1],cm_n,"Noisy")]:
    im=a.imshow(cm,cmap="Blues"); plt.colorbar(im,ax=a,fraction=.046)
    a.set_xticks(range(NUM_CLASSES)); a.set_yticks(range(NUM_CLASSES))
    a.set_xticklabels(SN,rotation=30,ha="right"); a.set_yticklabels(SN)
    th=cm.max()/2
    for i in range(NUM_CLASSES):
        for j in range(NUM_CLASSES):
            a.text(j,i,str(cm[i,j]),ha="center",va="center",fontsize=9,color="white" if cm[i,j]>th else "black")
    a.set_xlabel("Predicted"); a.set_ylabel("True"); a.set_title(f"Noise-Aware FedAvg — {title}")
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/confusion_matrices.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 18. ROC Curves

# %%
yb=label_binarize(y_test,classes=np.arange(NUM_CLASSES))
COLS=plt.cm.tab10(np.linspace(0,1,NUM_CLASSES))
fig,ax=plt.subplots(1,2,figsize=(13,6))
for a,yprob,title in [(ax[0],yp_clean,"Clean"),(ax[1],yp_noisy,"Noisy")]:
    for i in range(NUM_CLASSES):
        fpr,tpr,_=roc_curve(yb[:,i],yprob[:,i])
        a.plot(fpr,tpr,color=COLS[i],lw=1.8,label=f"{CLASS_NAMES[i]} (AUC={auc(fpr,tpr):.3f})")
    a.plot([0,1],[0,1],"k--",lw=1); a.set_xlabel("FPR"); a.set_ylabel("TPR")
    a.set_title(f"Noise-Aware FedAvg ROC — {title}"); a.legend(fontsize=9,loc="lower right"); a.grid(alpha=.3)
plt.tight_layout()
plt.savefig(f"{FIG_DIR}/roc_curves.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 19. Robustness Drop Visualization

# %%
MLABELS=["Accuracy","Precision","Recall","F1","AUC-ROC","QWK"]
cv=[mc[k] for k in MKEYS]; nv=[mn[k] for k in MKEYS]; dv=[rob[f"drop_{k}"] for k in MKEYS]
x=np.arange(len(MLABELS)); w=.35

fig,ax=plt.subplots(1,2,figsize=(13,5))
ax[0].bar(x-w/2,cv,w,label="Clean",color="#4CAF50",alpha=.85)
ax[0].bar(x+w/2,nv,w,label="Noisy",color="#E53935",alpha=.85)
for i,(a_,b_) in enumerate(zip(cv,nv)):
    ax[0].text(i-w/2,a_+.01,f"{a_:.3f}",ha="center",fontsize=8)
    ax[0].text(i+w/2,b_+.01,f"{b_:.3f}",ha="center",fontsize=8)
ax[0].set_xticks(x); ax[0].set_xticklabels(MLABELS); ax[0].set_ylim(0,1.1)
ax[0].set_title("Clean vs Noisy"); ax[0].legend(); ax[0].grid(axis="y",alpha=.3)

clrs=["#4CAF50" if d<=.05 else "#FFC107" if d<=.1 else "#F44336" for d in dv]
ax[1].bar(x,dv,color=clrs,alpha=.85,edgecolor="black",lw=.5)
for i,d in enumerate(dv): ax[1].text(i,d+.003,f"{d:+.3f}",ha="center",fontsize=9,fontweight="bold")
ax[1].set_xticks(x); ax[1].set_xticklabels(MLABELS)
ax[1].set_title("Robustness Drop (↓ = lebih robust)"); ax[1].axhline(0,color="k",lw=.8,ls="--"); ax[1].grid(axis="y",alpha=.3)
plt.suptitle(f"Noise-Aware FedAvg — {MODEL_NAME}"); plt.tight_layout()
plt.savefig(f"{FIG_DIR}/robustness_drop.png",dpi=300,bbox_inches="tight"); plt.show()

# %% [markdown]
# ## 20. Save Results + Summary

# %%
res={
    "experiment":EXPERIMENT_NAME,"model":MODEL_NAME,"paradigm":"Noise-Aware FedAvg",
    "use_noise_aug":USE_NOISE_AUG,"noisy_clients":NOISY_CLIENTS,
    "client_sizes":dict(zip(CLIENT_NAMES,[int(s) for s in csz])),
    "n_test":int(len(y_test)),
    "metrics_clean":mc,"metrics_noisy":mn,"robustness_drop":rob,
    "per_client":pcc,
    "confusion_matrix_clean":cm_c.tolist(),"confusion_matrix_noisy":cm_n.tolist(),
    "config":dict(seed=SEED,noisy_test_seed=NOISY_TEST_SEED,batch=BATCH_SIZE,lr=LR,
                  fl_rounds=FL_ROUNDS,local_epochs=LOCAL_EPOCHS,
                  stage1_rounds=STAGE1_ROUNDS,unfreeze_n=UNFREEZE_N,
                  noise_prob=NOISE_PROB,blur_prob=BLUR_PROB,bright_prob=BRIGHT_PROB)
}
with open(f"{LOG_DIR}/results.json","w") as f: json.dump(res,f,indent=2)

row={"experiment":EXPERIMENT_NAME,"paradigm":"Noise-Aware FedAvg","model":MODEL_NAME}
row.update({f"clean_{k}":mc[k] for k in MKEYS})
row.update({f"noisy_{k}":mn[k] for k in MKEYS})
row.update(rob)
pd.DataFrame([row]).to_csv(f"{LOG_DIR}/summary_row.csv",index=False)
print(f"Saved to: {RES}")

print("\n"+"="*65)
print(f"  EXP3 NOISE-AWARE FEDAVG — DONE")
print("="*65)
print(f"  Noisy clients: {NOISY_CLIENTS}")
print(f"  CLEAN  | Acc:{mc['accuracy']:.4f}  F1:{mc['f1_macro']:.4f}  AUC:{mc['auc_roc']:.4f}  QWK:{mc['qwk']:.4f}")
print(f"  NOISY  | Acc:{mn['accuracy']:.4f}  F1:{mn['f1_macro']:.4f}  AUC:{mn['auc_roc']:.4f}  QWK:{mn['qwk']:.4f}")
print(f"  DROP   | Acc:{rob['drop_accuracy']:+.4f}  F1:{rob['drop_f1_macro']:+.4f}  AUC:{rob['drop_auc_roc']:+.4f}  QWK:{rob['drop_qwk']:+.4f}")
print("="*65)
print("\n  >>> Bandingin DROP ini sama Exp1 & Exp2 — harusnya PALING KECIL <<<")
# Out:
# Saved to: /content/drive/MyDrive/Binus/Semester_4/Research_Methodology/Result/MobileNetV2/exp3_noise_aware_fl
#
# =================================================================
#   EXP3 NOISE-AWARE FEDAVG — DONE
# =================================================================
#   Noisy clients: ['DDR', 'EyePACS', 'APTOS']
#   CLEAN  | Acc:0.3850  F1:0.3784  AUC:0.7496  QWK:0.5664
#   NOISY  | Acc:0.1258  F1:0.1046  AUC:0.5723  QWK:0.0697
#   DROP   | Acc:+0.2593  F1:+0.2738  AUC:+0.1773  QWK:+0.4967
# =================================================================
#
#   >>> Bandingin DROP ini sama Exp1 & Exp2 — harusnya PALING KECIL <<<
